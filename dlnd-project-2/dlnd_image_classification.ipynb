# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x / 255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
encodings = np.eye(10,dtype=int)

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return encodings[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, *image_shape), name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None), name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal([*conv_ksize, x_tensor.shape.as_list()[-1], conv_num_outputs], stddev=0.1))
    conv = tf.nn.conv2d(x_tensor, weights, [1, *conv_strides, 1], "SAME", use_cudnn_on_gpu=None, data_format=None, name="conv2d")
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    h = tf.nn.relu(tf.add(conv, bias))
    maxpool = tf.nn.max_pool(h, [1, *pool_ksize, 1], [1, *pool_strides, 1], "SAME", data_format='NHWC', name="maxpool")

    return maxpool


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    #return tf.contrib.layers.fully_connected(x_tensor, num_outputs)
    x_tensor_shape = x_tensor.get_shape().as_list()[1:][0]
    weight = tf.Variable(tf.truncated_normal([x_tensor_shape, num_outputs], stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.nn.relu(tf.add(tf.matmul(x_tensor, weight), bias))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_tensor_shape = x_tensor.get_shape().as_list()[1:][0]
    weight = tf.Variable(tf.truncated_normal([x_tensor_shape, num_outputs], stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_out1 = tf.nn.dropout(conv2d_maxpool(x, 20, (16, 16), (2, 2), (2, 2), (2, 2)), keep_prob)
    print(conv_out1.get_shape())
    conv_out2 = tf.nn.dropout(conv2d_maxpool(conv_out1, 80, (8, 8), (1, 1), (2, 2), (2, 2)), keep_prob)
    print(conv_out2.get_shape())
    conv_out3 = tf.nn.dropout(conv2d_maxpool(conv_out2, 200, (4, 4), (2, 2), (2, 2), (2, 2)), keep_prob)
    print(conv_out3.get_shape())

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv_out3)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    full1 = fully_conn(flat, 300)
    full2 = tf.nn.dropout(fully_conn(full1, 150), keep_prob)
    full3 = fully_conn(full2, 50)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(full3, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# (?, 8, 8, 20)
# (?, 4, 4, 80)
# (?, 1, 1, 200)
# (?, 8, 8, 20)
# (?, 4, 4, 80)
# (?, 1, 1, 200)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={keep_prob:keep_probability, x:feature_batch, y:label_batch})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    c = session.run([cost], feed_dict={keep_prob:1.0, x:valid_features, y:valid_labels})
    a = session.run([accuracy], feed_dict={keep_prob:1.0, x:valid_features, y:valid_labels})
    print('Validation Cost {}'.format(c))
    print('Validation Accuracy {}'.format(a))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 64
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Validation Cost [2.2988284]
# Validation Accuracy [0.103]
# Epoch  2, CIFAR-10 Batch 1:  Validation Cost [2.1974125]
# Validation Accuracy [0.17379999]
# Epoch  3, CIFAR-10 Batch 1:  Validation Cost [2.1027656]
# Validation Accuracy [0.21779999]
# Epoch  4, CIFAR-10 Batch 1:  Validation Cost [2.1030488]
# Validation Accuracy [0.2128]
# Epoch  5, CIFAR-10 Batch 1:  Validation Cost [2.0549202]
# Validation Accuracy [0.24159998]
# Epoch  6, CIFAR-10 Batch 1:  Validation Cost [2.0001059]
# Validation Accuracy [0.24699999]
# Epoch  7, CIFAR-10 Batch 1:  Validation Cost [1.9722863]
# Validation Accuracy [0.25739998]
# Epoch  8, CIFAR-10 Batch 1:  Validation Cost [1.9607493]
# Validation Accuracy [0.27320001]
# Epoch  9, CIFAR-10 Batch 1:  Validation Cost [2.0180955]
# Validation Accuracy [0.26279998]
# Epoch 10, CIFAR-10 Batch 1:  Validation Cost [1.9550091]
# Validation Accuracy [0.2834]
# Epoch 11, CIFAR-10 Batch 1:  Validation Cost [1.9059352]
# Validation Accuracy [0.29119998]
# Epoch 12, CIFAR-10 Batch 1:  Validation Cost [1.8669842]
# Validation Accuracy [0.31039998]
# Epoch 13, CIFAR-10 Batch 1:  Validation Cost [1.8415112]
# Validation Accuracy [0.31699997]
# Epoch 14, CIFAR-10 Batch 1:  Validation Cost [1.8232135]
# Validation Accuracy [0.32799998]
# Epoch 15, CIFAR-10 Batch 1:  Validation Cost [1.8144186]
# Validation Accuracy [0.33499995]
# Epoch 16, CIFAR-10 Batch 1:  Validation Cost [1.774663]
# Validation Accuracy [0.35279998]
# Epoch 17, CIFAR-10 Batch 1:  Validation Cost [1.7577281]
# Validation Accuracy [0.35879999]
# Epoch 18, CIFAR-10 Batch 1:  Validation Cost [1.7428077]
# Validation Accuracy [0.35819995]
# Epoch 19, CIFAR-10 Batch 1:  Validation Cost [1.7469929]
# Validation Accuracy [0.3682]
# Epoch 20, CIFAR-10 Batch 1:  Validation Cost [1.7072012]
# Validation Accuracy [0.37239999]
# Epoch 21, CIFAR-10 Batch 1:  Validation Cost [1.6866862]
# Validation Accuracy [0.37940001]
# Epoch 22, CIFAR-10 Batch 1:  Validation Cost [1.6830103]
# Validation Accuracy [0.37939996]
# Epoch 23, CIFAR-10 Batch 1:  Validation Cost [1.6630523]
# Validation Accuracy [0.39419997]
# Epoch 24, CIFAR-10 Batch 1:  Validation Cost [1.6492056]
# Validation Accuracy [0.39799997]
# Epoch 25, CIFAR-10 Batch 1:  Validation Cost [1.6866406]
# Validation Accuracy [0.38539997]
# Epoch 26, CIFAR-10 Batch 1:  Validation Cost [1.6428144]
# Validation Accuracy [0.40979999]
# Epoch 27, CIFAR-10 Batch 1:  Validation Cost [1.61813]
# Validation Accuracy [0.40759996]
# Epoch 28, CIFAR-10 Batch 1:  Validation Cost [1.6302849]
# Validation Accuracy [0.39839995]
# Epoch 29, CIFAR-10 Batch 1:  Validation Cost [1.6071659]
# Validation Accuracy [0.42120001]
# Epoch 30, CIFAR-10 Batch 1:  Validation Cost [1.6384302]
# Validation Accuracy [0.41439998]
# Epoch 31, CIFAR-10 Batch 1:  Validation Cost [1.5874107]
# Validation Accuracy [0.42459995]
# Epoch 32, CIFAR-10 Batch 1:  Validation Cost [1.5811528]
# Validation Accuracy [0.42739999]
# Epoch 33, CIFAR-10 Batch 1:  Validation Cost [1.5893281]
# Validation Accuracy [0.42099997]
# Epoch 34, CIFAR-10 Batch 1:  Validation Cost [1.6272532]
# Validation Accuracy [0.4188]
# Epoch 35, CIFAR-10 Batch 1:  Validation Cost [1.6029038]
# Validation Accuracy [0.42539996]
# Epoch 36, CIFAR-10 Batch 1:  Validation Cost [1.5809712]
# Validation Accuracy [0.43200001]
# Epoch 37, CIFAR-10 Batch 1:  Validation Cost [1.5397446]
# Validation Accuracy [0.44919994]
# Epoch 38, CIFAR-10 Batch 1:  Validation Cost [1.5847758]
# Validation Accuracy [0.42599997]
# Epoch 39, CIFAR-10 Batch 1:  Validation Cost [1.5389638]
# Validation Accuracy [0.44579995]
# Epoch 40, CIFAR-10 Batch 1:  Validation Cost [1.556505]
# Validation Accuracy [0.44739997]
# Epoch 41, CIFAR-10 Batch 1:  Validation Cost [1.5675421]
# Validation Accuracy [0.44559997]
# Epoch 42, CIFAR-10 Batch 1:  Validation Cost [1.5229797]
# Validation Accuracy [0.45019996]
# Epoch 43, CIFAR-10 Batch 1:  Validation Cost [1.5362518]
# Validation Accuracy [0.45819998]
# Epoch 44, CIFAR-10 Batch 1:  Validation Cost [1.538754]
# Validation Accuracy [0.45079994]
# Epoch 45, CIFAR-10 Batch 1:  Validation Cost [1.5153985]
# Validation Accuracy [0.44639996]
# Epoch 46, CIFAR-10 Batch 1:  Validation Cost [1.513553]
# Validation Accuracy [0.45539996]
# Epoch 47, CIFAR-10 Batch 1:  Validation Cost [1.5200778]
# Validation Accuracy [0.45519996]
# Epoch 48, CIFAR-10 Batch 1:  Validation Cost [1.5083541]
# Validation Accuracy [0.45919994]
# Epoch 49, CIFAR-10 Batch 1:  Validation Cost [1.4969602]
# Validation Accuracy [0.46659997]
# Epoch 50, CIFAR-10 Batch 1:  Validation Cost [1.5038872]
# Validation Accuracy [0.46039999]
# Epoch 51, CIFAR-10 Batch 1:  Validation Cost [1.5293746]
# Validation Accuracy [0.46079993]
# Epoch 52, CIFAR-10 Batch 1:  Validation Cost [1.5168222]
# Validation Accuracy [0.45239994]
# Epoch 53, CIFAR-10 Batch 1:  Validation Cost [1.4832938]
# Validation Accuracy [0.47219995]
# Epoch 54, CIFAR-10 Batch 1:  Validation Cost [1.5132411]
# Validation Accuracy [0.46099997]
# Epoch 55, CIFAR-10 Batch 1:  Validation Cost [1.4936602]
# Validation Accuracy [0.46219999]
# Epoch 56, CIFAR-10 Batch 1:  Validation Cost [1.4895912]
# Validation Accuracy [0.4738]
# Epoch 57, CIFAR-10 Batch 1:  Validation Cost [1.4944823]
# Validation Accuracy [0.47019997]
# Epoch 58, CIFAR-10 Batch 1:  Validation Cost [1.4853477]
# Validation Accuracy [0.46439996]
# Epoch 59, CIFAR-10 Batch 1:  Validation Cost [1.4551637]
# Validation Accuracy [0.47179994]
# Epoch 60, CIFAR-10 Batch 1:  Validation Cost [1.4806107]
# Validation Accuracy [0.47039998]
# Epoch 61, CIFAR-10 Batch 1:  Validation Cost [1.4602993]
# Validation Accuracy [0.47119999]
# Epoch 62, CIFAR-10 Batch 1:  Validation Cost [1.4787827]
# Validation Accuracy [0.46479997]
# Epoch 63, CIFAR-10 Batch 1:  Validation Cost [1.4805162]
# Validation Accuracy [0.46639997]
# Epoch 64, CIFAR-10 Batch 1:  Validation Cost [1.4497665]
# Validation Accuracy [0.47919995]
# Epoch 65, CIFAR-10 Batch 1:  Validation Cost [1.470037]
# Validation Accuracy [0.47359997]
# Epoch 66, CIFAR-10 Batch 1:  Validation Cost [1.4541466]
# Validation Accuracy [0.47119999]
# Epoch 67, CIFAR-10 Batch 1:  Validation Cost [1.4382317]
# Validation Accuracy [0.48859996]
# Epoch 68, CIFAR-10 Batch 1:  Validation Cost [1.4310375]
# Validation Accuracy [0.49039996]
# Epoch 69, CIFAR-10 Batch 1:  Validation Cost [1.4485353]
# Validation Accuracy [0.47219998]
# Epoch 70, CIFAR-10 Batch 1:  Validation Cost [1.4501312]
# Validation Accuracy [0.48919997]
# Epoch 71, CIFAR-10 Batch 1:  Validation Cost [1.4280356]
# Validation Accuracy [0.49139991]
# Epoch 72, CIFAR-10 Batch 1:  Validation Cost [1.4483514]
# Validation Accuracy [0.48659992]
# Epoch 73, CIFAR-10 Batch 1:  Validation Cost [1.4467558]
# Validation Accuracy [0.48619992]
# Epoch 74, CIFAR-10 Batch 1:  Validation Cost [1.433018]
# Validation Accuracy [0.48959994]
# Epoch 75, CIFAR-10 Batch 1:  Validation Cost [1.4291093]
# Validation Accuracy [0.48779994]
# Epoch 76, CIFAR-10 Batch 1:  Validation Cost [1.425983]
# Validation Accuracy [0.48659992]
# Epoch 77, CIFAR-10 Batch 1:  Validation Cost [1.4247847]
# Validation Accuracy [0.48739997]
# Epoch 78, CIFAR-10 Batch 1:  Validation Cost [1.4151654]
# Validation Accuracy [0.49679992]
# Epoch 79, CIFAR-10 Batch 1:  Validation Cost [1.4318128]
# Validation Accuracy [0.48739994]
# Epoch 80, CIFAR-10 Batch 1:  Validation Cost [1.4434862]
# Validation Accuracy [0.48879996]
# Epoch 81, CIFAR-10 Batch 1:  Validation Cost [1.417189]
# Validation Accuracy [0.48919994]
# Epoch 82, CIFAR-10 Batch 1:  Validation Cost [1.4189073]
# Validation Accuracy [0.48839995]
# Epoch 83, CIFAR-10 Batch 1:  Validation Cost [1.5431886]
# Validation Accuracy [0.44099998]
# Epoch 84, CIFAR-10 Batch 1:  Validation Cost [1.4239281]
# Validation Accuracy [0.49359995]
# Epoch 85, CIFAR-10 Batch 1:  Validation Cost [1.4119873]
# Validation Accuracy [0.49619997]
# Epoch 86, CIFAR-10 Batch 1:  Validation Cost [1.4254824]
# Validation Accuracy [0.48559996]
# Epoch 87, CIFAR-10 Batch 1:  Validation Cost [1.4417659]
# Validation Accuracy [0.49339998]
# Epoch 88, CIFAR-10 Batch 1:  Validation Cost [1.4207745]
# Validation Accuracy [0.49139994]
# Epoch 89, CIFAR-10 Batch 1:  Validation Cost [1.4337987]
# Validation Accuracy [0.498]
# Epoch 90, CIFAR-10 Batch 1:  Validation Cost [1.415858]
# Validation Accuracy [0.48919997]
# Epoch 91, CIFAR-10 Batch 1:  Validation Cost [1.4190681]
# Validation Accuracy [0.49439994]
# Epoch 92, CIFAR-10 Batch 1:  Validation Cost [1.417546]
# Validation Accuracy [0.48839995]
# Epoch 93, CIFAR-10 Batch 1:  Validation Cost [1.406772]
# Validation Accuracy [0.49979997]
# Epoch 94, CIFAR-10 Batch 1:  Validation Cost [1.3967477]
# Validation Accuracy [0.505]
# Epoch 95, CIFAR-10 Batch 1:  Validation Cost [1.4035797]
# Validation Accuracy [0.49279994]
# Epoch 96, CIFAR-10 Batch 1:  Validation Cost [1.40838]
# Validation Accuracy [0.49579996]
# Epoch 97, CIFAR-10 Batch 1:  Validation Cost [1.4061637]
# Validation Accuracy [0.49839994]
# Epoch 98, CIFAR-10 Batch 1:  Validation Cost [1.3878957]
# Validation Accuracy [0.50419992]
# Epoch 99, CIFAR-10 Batch 1:  Validation Cost [1.3964149]
# Validation Accuracy [0.49799997]
# Epoch 100, CIFAR-10 Batch 1:  Validation Cost [1.4124361]
# Validation Accuracy [0.49999994]
# Epoch 101, CIFAR-10 Batch 1:  Validation Cost [1.4003159]
# Validation Accuracy [0.50419992]
# Epoch 102, CIFAR-10 Batch 1:  Validation Cost [1.3949118]
# Validation Accuracy [0.50619996]
# Epoch 103, CIFAR-10 Batch 1:  Validation Cost [1.3978469]
# Validation Accuracy [0.49959993]
# Epoch 104, CIFAR-10 Batch 1:  Validation Cost [1.3855811]
# Validation Accuracy [0.50719994]
# Epoch 105, CIFAR-10 Batch 1:  Validation Cost [1.3910556]
# Validation Accuracy [0.50099993]
# Epoch 106, CIFAR-10 Batch 1:  Validation Cost [1.4121965]
# Validation Accuracy [0.4824]
# Epoch 107, CIFAR-10 Batch 1:  Validation Cost [1.4038587]
# Validation Accuracy [0.49419996]
# Epoch 108, CIFAR-10 Batch 1:  Validation Cost [1.3767157]
# Validation Accuracy [0.51119995]
# Epoch 109, CIFAR-10 Batch 1:  Validation Cost [1.400088]
# Validation Accuracy [0.50379997]
# Epoch 110, CIFAR-10 Batch 1:  Validation Cost [1.3941847]
# Validation Accuracy [0.50199997]
# Epoch 111, CIFAR-10 Batch 1:  Validation Cost [1.3943446]
# Validation Accuracy [0.495]
# Epoch 112, CIFAR-10 Batch 1:  Validation Cost [1.3882811]
# Validation Accuracy [0.50439996]
# Epoch 113, CIFAR-10 Batch 1:  Validation Cost [1.3765352]
# Validation Accuracy [0.50459993]
# Epoch 114, CIFAR-10 Batch 1:  Validation Cost [1.3940656]
# Validation Accuracy [0.50479996]
# Epoch 115, CIFAR-10 Batch 1:  Validation Cost [1.3736511]
# Validation Accuracy [0.51839995]
# Epoch 116, CIFAR-10 Batch 1:  Validation Cost [1.3798546]
# Validation Accuracy [0.51059997]
# Epoch 117, CIFAR-10 Batch 1:  Validation Cost [1.3971424]
# Validation Accuracy [0.50219995]
# Epoch 118, CIFAR-10 Batch 1:  Validation Cost [1.3901474]
# Validation Accuracy [0.50059992]
# Epoch 119, CIFAR-10 Batch 1:  Validation Cost [1.3959628]
# Validation Accuracy [0.50819999]
# Epoch 120, CIFAR-10 Batch 1:  Validation Cost [1.3911355]
# Validation Accuracy [0.50779992]
# Epoch 121, CIFAR-10 Batch 1:  Validation Cost [1.3967346]
# Validation Accuracy [0.49899995]
# Epoch 122, CIFAR-10 Batch 1:  Validation Cost [1.3912945]
# Validation Accuracy [0.50219995]
# Epoch 123, CIFAR-10 Batch 1:  Validation Cost [1.383044]
# Validation Accuracy [0.49899995]
# Epoch 124, CIFAR-10 Batch 1:  Validation Cost [1.4157195]
# Validation Accuracy [0.49239993]
# Epoch 125, CIFAR-10 Batch 1:  Validation Cost [1.3750007]
# Validation Accuracy [0.50859994]
# Epoch 126, CIFAR-10 Batch 1:  Validation Cost [1.3868454]
# Validation Accuracy [0.50859994]
# Epoch 127, CIFAR-10 Batch 1:  Validation Cost [1.3765897]
# Validation Accuracy [0.51599991]
# Epoch 128, CIFAR-10 Batch 1:  Validation Cost [1.3841434]
# Validation Accuracy [0.50119996]
# Epoch 129, CIFAR-10 Batch 1:  Validation Cost [1.3709891]
# Validation Accuracy [0.51839995]
# Epoch 130, CIFAR-10 Batch 1:  Validation Cost [1.3846991]
# Validation Accuracy [0.51179999]
# Epoch 131, CIFAR-10 Batch 1:  Validation Cost [1.3722353]
# Validation Accuracy [0.51619995]
# Epoch 132, CIFAR-10 Batch 1:  Validation Cost [1.3838687]
# Validation Accuracy [0.51139992]
# Epoch 133, CIFAR-10 Batch 1:  Validation Cost [1.3802159]
# Validation Accuracy [0.50979996]
# Epoch 134, CIFAR-10 Batch 1:  Validation Cost [1.3714912]
# Validation Accuracy [0.51859999]
# Epoch 135, CIFAR-10 Batch 1:  Validation Cost [1.398829]
# Validation Accuracy [0.50919998]
# Epoch 136, CIFAR-10 Batch 1:  Validation Cost [1.3589901]
# Validation Accuracy [0.52119994]
# Epoch 137, CIFAR-10 Batch 1:  Validation Cost [1.3843187]
# Validation Accuracy [0.50839996]
# Epoch 138, CIFAR-10 Batch 1:  Validation Cost [1.37422]
# Validation Accuracy [0.51379991]
# Epoch 139, CIFAR-10 Batch 1:  Validation Cost [1.3929663]
# Validation Accuracy [0.50919992]
# Epoch 140, CIFAR-10 Batch 1:  Validation Cost [1.3624899]
# Validation Accuracy [0.50859994]
# Epoch 141, CIFAR-10 Batch 1:  Validation Cost [1.3705504]
# Validation Accuracy [0.51099998]
# Epoch 142, CIFAR-10 Batch 1:  Validation Cost [1.391752]
# Validation Accuracy [0.50479996]
# Epoch 143, CIFAR-10 Batch 1:  Validation Cost [1.400686]
# Validation Accuracy [0.49859995]
# Epoch 144, CIFAR-10 Batch 1:  Validation Cost [1.368268]
# Validation Accuracy [0.51559997]
# Epoch 145, CIFAR-10 Batch 1:  Validation Cost [1.375616]
# Validation Accuracy [0.52219993]
# Epoch 146, CIFAR-10 Batch 1:  Validation Cost [1.3850367]
# Validation Accuracy [0.51639998]
# Epoch 147, CIFAR-10 Batch 1:  Validation Cost [1.3679705]
# Validation Accuracy [0.50619996]
# Epoch 148, CIFAR-10 Batch 1:  Validation Cost [1.3652933]
# Validation Accuracy [0.51139998]
# Epoch 149, CIFAR-10 Batch 1:  Validation Cost [1.3630025]
# Validation Accuracy [0.51479995]
# Epoch 150, CIFAR-10 Batch 1:  Validation Cost [1.3814771]
# Validation Accuracy [0.51039994]
# Epoch 151, CIFAR-10 Batch 1:  Validation Cost [1.3662065]
# Validation Accuracy [0.52179992]
# Epoch 152, CIFAR-10 Batch 1:  Validation Cost [1.3843598]
# Validation Accuracy [0.49839994]
# Epoch 153, CIFAR-10 Batch 1:  Validation Cost [1.3750552]
# Validation Accuracy [0.50959992]
# Epoch 154, CIFAR-10 Batch 1:  Validation Cost [1.3554432]
# Validation Accuracy [0.51839995]
# Epoch 155, CIFAR-10 Batch 1:  Validation Cost [1.351529]
# Validation Accuracy [0.52039993]
# Epoch 156, CIFAR-10 Batch 1:  Validation Cost [1.377076]
# Validation Accuracy [0.51799995]
# Epoch 157, CIFAR-10 Batch 1:  Validation Cost [1.3622298]
# Validation Accuracy [0.51319999]
# Epoch 158, CIFAR-10 Batch 1:  Validation Cost [1.3724028]
# Validation Accuracy [0.51739991]
# Epoch 159, CIFAR-10 Batch 1:  Validation Cost [1.3784143]
# Validation Accuracy [0.51399994]
# Epoch 160, CIFAR-10 Batch 1:  Validation Cost [1.369271]
# Validation Accuracy [0.51219994]
# Epoch 161, CIFAR-10 Batch 1:  Validation Cost [1.3528404]
# Validation Accuracy [0.51799995]
# Epoch 162, CIFAR-10 Batch 1:  Validation Cost [1.3674805]
# Validation Accuracy [0.51579994]
# Epoch 163, CIFAR-10 Batch 1:  Validation Cost [1.3519071]
# Validation Accuracy [0.52499992]
# Epoch 164, CIFAR-10 Batch 1:  Validation Cost [1.3820597]
# Validation Accuracy [0.50439996]
# Epoch 165, CIFAR-10 Batch 1:  Validation Cost [1.352111]
# Validation Accuracy [0.51899993]
# Epoch 166, CIFAR-10 Batch 1:  Validation Cost [1.3737241]
# Validation Accuracy [0.50459999]
# Epoch 167, CIFAR-10 Batch 1:  Validation Cost [1.3603624]
# Validation Accuracy [0.51919997]
# Epoch 168, CIFAR-10 Batch 1:  Validation Cost [1.3773718]
# Validation Accuracy [0.51599991]
# Epoch 169, CIFAR-10 Batch 1:  Validation Cost [1.372454]
# Validation Accuracy [0.51159996]
# Epoch 170, CIFAR-10 Batch 1:  Validation Cost [1.3800973]
# Validation Accuracy [0.50979996]
# Epoch 171, CIFAR-10 Batch 1:  Validation Cost [1.3907546]
# Validation Accuracy [0.51599997]
# Epoch 172, CIFAR-10 Batch 1:  Validation Cost [1.3551]
# Validation Accuracy [0.52059996]
# Epoch 173, CIFAR-10 Batch 1:  Validation Cost [1.3801842]
# Validation Accuracy [0.52059996]
# Epoch 174, CIFAR-10 Batch 1:  Validation Cost [1.3919827]
# Validation Accuracy [0.51199996]
# Epoch 175, CIFAR-10 Batch 1:  Validation Cost [1.354436]
# Validation Accuracy [0.523]
# Epoch 176, CIFAR-10 Batch 1:  Validation Cost [1.3640642]
# Validation Accuracy [0.51999992]
# Epoch 177, CIFAR-10 Batch 1:  Validation Cost [1.3494849]
# Validation Accuracy [0.51919997]
# Epoch 178, CIFAR-10 Batch 1:  Validation Cost [1.3830521]
# Validation Accuracy [0.50979996]
# Epoch 179, CIFAR-10 Batch 1:  Validation Cost [1.3617224]
# Validation Accuracy [0.51619989]
# Epoch 180, CIFAR-10 Batch 1:  Validation Cost [1.3968738]
# Validation Accuracy [0.50239992]
# Epoch 181, CIFAR-10 Batch 1:  Validation Cost [1.3554114]
# Validation Accuracy [0.52099997]
# Epoch 182, CIFAR-10 Batch 1:  Validation Cost [1.3607079]
# Validation Accuracy [0.52659994]
# Epoch 183, CIFAR-10 Batch 1:  Validation Cost [1.3815553]
# Validation Accuracy [0.51319999]
# Epoch 184, CIFAR-10 Batch 1:  Validation Cost [1.354376]
# Validation Accuracy [0.5223999]
# Epoch 185, CIFAR-10 Batch 1:  Validation Cost [1.3930602]
# Validation Accuracy [0.51279998]
# Epoch 186, CIFAR-10 Batch 1:  Validation Cost [1.3637205]
# Validation Accuracy [0.52699995]
# Epoch 187, CIFAR-10 Batch 1:  Validation Cost [1.3521614]
# Validation Accuracy [0.52759993]
# Epoch 188, CIFAR-10 Batch 1:  Validation Cost [1.3631191]
# Validation Accuracy [0.51799995]
# Epoch 189, CIFAR-10 Batch 1:  Validation Cost [1.3882828]
# Validation Accuracy [0.50919998]
# Epoch 190, CIFAR-10 Batch 1:  Validation Cost [1.3826221]
# Validation Accuracy [0.5101999]
# Epoch 191, CIFAR-10 Batch 1:  Validation Cost [1.3672339]
# Validation Accuracy [0.51319993]
# Epoch 192, CIFAR-10 Batch 1:  Validation Cost [1.3666453]
# Validation Accuracy [0.51979995]
# Epoch 193, CIFAR-10 Batch 1:  Validation Cost [1.403293]
# Validation Accuracy [0.50519991]
# Epoch 194, CIFAR-10 Batch 1:  Validation Cost [1.3685715]
# Validation Accuracy [0.51739997]
# Epoch 195, CIFAR-10 Batch 1:  Validation Cost [1.3640314]
# Validation Accuracy [0.51559997]
# Epoch 196, CIFAR-10 Batch 1:  Validation Cost [1.3657138]
# Validation Accuracy [0.51959997]
# Epoch 197, CIFAR-10 Batch 1:  Validation Cost [1.3588591]
# Validation Accuracy [0.52879995]
# Epoch 198, CIFAR-10 Batch 1:  Validation Cost [1.366492]
# Validation Accuracy [0.52459997]
# Epoch 199, CIFAR-10 Batch 1:  Validation Cost [1.3703852]
# Validation Accuracy [0.51559991]
# Epoch 200, CIFAR-10 Batch 1:  Validation Cost [1.3732775]
# Validation Accuracy [0.51839995]

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Validation Cost [2.2841587]
# Validation Accuracy [0.1522]
# Epoch  1, CIFAR-10 Batch 2:  Validation Cost [2.178499]
# Validation Accuracy [0.19899999]
# Epoch  1, CIFAR-10 Batch 3:  Validation Cost [2.096045]
# Validation Accuracy [0.19219999]
# Epoch  1, CIFAR-10 Batch 4:  Validation Cost [2.053067]
# Validation Accuracy [0.21999998]
# Epoch  1, CIFAR-10 Batch 5:  Validation Cost [2.036098]
# Validation Accuracy [0.2414]
# Epoch  2, CIFAR-10 Batch 1:  Validation Cost [2.0100412]
# Validation Accuracy [0.25159997]
# Epoch  2, CIFAR-10 Batch 2:  Validation Cost [2.0784528]
# Validation Accuracy [0.22159998]
# Epoch  2, CIFAR-10 Batch 3:  Validation Cost [1.9589282]
# Validation Accuracy [0.27340001]
# Epoch  2, CIFAR-10 Batch 4:  Validation Cost [1.9451336]
# Validation Accuracy [0.27059999]
# Epoch  2, CIFAR-10 Batch 5:  Validation Cost [1.9346899]
# Validation Accuracy [0.28159997]
# Epoch  3, CIFAR-10 Batch 1:  Validation Cost [1.9026673]
# Validation Accuracy [0.32279998]
# Epoch  3, CIFAR-10 Batch 2:  Validation Cost [1.8673438]
# Validation Accuracy [0.31319997]
# Epoch  3, CIFAR-10 Batch 3:  Validation Cost [1.8039318]
# Validation Accuracy [0.34339997]
# Epoch  3, CIFAR-10 Batch 4:  Validation Cost [1.8156013]
# Validation Accuracy [0.35939997]
# Epoch  3, CIFAR-10 Batch 5:  Validation Cost [1.8200198]
# Validation Accuracy [0.34759998]
# Epoch  4, CIFAR-10 Batch 1:  Validation Cost [1.8163793]
# Validation Accuracy [0.35279998]
# Epoch  4, CIFAR-10 Batch 2:  Validation Cost [1.8558202]
# Validation Accuracy [0.31259996]
# Epoch  4, CIFAR-10 Batch 3:  Validation Cost [1.7644949]
# Validation Accuracy [0.36320001]
# Epoch  4, CIFAR-10 Batch 4:  Validation Cost [1.7354556]
# Validation Accuracy [0.3908]
# Epoch  4, CIFAR-10 Batch 5:  Validation Cost [1.7461907]
# Validation Accuracy [0.3766]
# Epoch  5, CIFAR-10 Batch 1:  Validation Cost [1.7337687]
# Validation Accuracy [0.38779998]
# Epoch  5, CIFAR-10 Batch 2:  Validation Cost [1.8807555]
# Validation Accuracy [0.32979998]
# Epoch  5, CIFAR-10 Batch 3:  Validation Cost [1.7586315]
# Validation Accuracy [0.37580001]
# Epoch  5, CIFAR-10 Batch 4:  Validation Cost [1.6662939]
# Validation Accuracy [0.39139998]
# Epoch  5, CIFAR-10 Batch 5:  Validation Cost [1.7405814]
# Validation Accuracy [0.39279997]
# Epoch  6, CIFAR-10 Batch 1:  Validation Cost [1.7101974]
# Validation Accuracy [0.38979998]
# Epoch  6, CIFAR-10 Batch 2:  Validation Cost [1.7333255]
# Validation Accuracy [0.37979996]
# Epoch  6, CIFAR-10 Batch 3:  Validation Cost [1.6662394]
# Validation Accuracy [0.39899999]
# Epoch  6, CIFAR-10 Batch 4:  Validation Cost [1.6389439]
# Validation Accuracy [0.41100001]
# Epoch  6, CIFAR-10 Batch 5:  Validation Cost [1.7384404]
# Validation Accuracy [0.38599998]
# Epoch  7, CIFAR-10 Batch 1:  Validation Cost [1.6418217]
# Validation Accuracy [0.40759999]
# Epoch  7, CIFAR-10 Batch 2:  Validation Cost [1.6660904]
# Validation Accuracy [0.41679996]
# Epoch  7, CIFAR-10 Batch 3:  Validation Cost [1.6556628]
# Validation Accuracy [0.39559999]
# Epoch  7, CIFAR-10 Batch 4:  Validation Cost [1.6069382]
# Validation Accuracy [0.42680001]
# Epoch  7, CIFAR-10 Batch 5:  Validation Cost [1.6740084]
# Validation Accuracy [0.41139996]
# Epoch  8, CIFAR-10 Batch 1:  Validation Cost [1.6016017]
# Validation Accuracy [0.426]
# Epoch  8, CIFAR-10 Batch 2:  Validation Cost [1.5810308]
# Validation Accuracy [0.44099995]
# Epoch  8, CIFAR-10 Batch 3:  Validation Cost [1.5824491]
# Validation Accuracy [0.42859995]
# Epoch  8, CIFAR-10 Batch 4:  Validation Cost [1.5608284]
# Validation Accuracy [0.44159997]
# Epoch  8, CIFAR-10 Batch 5:  Validation Cost [1.6278038]
# Validation Accuracy [0.4224]
# Epoch  9, CIFAR-10 Batch 1:  Validation Cost [1.6071419]
# Validation Accuracy [0.43339995]
# Epoch  9, CIFAR-10 Batch 2:  Validation Cost [1.6051985]
# Validation Accuracy [0.43479997]
# Epoch  9, CIFAR-10 Batch 3:  Validation Cost [1.5918472]
# Validation Accuracy [0.43359995]
# Epoch  9, CIFAR-10 Batch 4:  Validation Cost [1.5645392]
# Validation Accuracy [0.43879998]
# Epoch  9, CIFAR-10 Batch 5:  Validation Cost [1.6044598]
# Validation Accuracy [0.43059999]
# Epoch 10, CIFAR-10 Batch 1:  Validation Cost [1.5454309]
# Validation Accuracy [0.4542]
# Epoch 10, CIFAR-10 Batch 2:  Validation Cost [1.5604604]
# Validation Accuracy [0.45159999]
# Epoch 10, CIFAR-10 Batch 3:  Validation Cost [1.5176293]
# Validation Accuracy [0.45499998]
# Epoch 10, CIFAR-10 Batch 4:  Validation Cost [1.5256985]
# Validation Accuracy [0.45519996]
# Epoch 10, CIFAR-10 Batch 5:  Validation Cost [1.5346755]
# Validation Accuracy [0.47199994]
# Epoch 11, CIFAR-10 Batch 1:  Validation Cost [1.5065485]
# Validation Accuracy [0.46199992]
# Epoch 11, CIFAR-10 Batch 2:  Validation Cost [1.52665]
# Validation Accuracy [0.45119995]
# Epoch 11, CIFAR-10 Batch 3:  Validation Cost [1.5641243]
# Validation Accuracy [0.43799996]
# Epoch 11, CIFAR-10 Batch 4:  Validation Cost [1.5081441]
# Validation Accuracy [0.45479995]
# Epoch 11, CIFAR-10 Batch 5:  Validation Cost [1.5008334]
# Validation Accuracy [0.46359995]
# Epoch 12, CIFAR-10 Batch 1:  Validation Cost [1.5000808]
# Validation Accuracy [0.47019994]
# Epoch 12, CIFAR-10 Batch 2:  Validation Cost [1.534904]
# Validation Accuracy [0.45739996]
# Epoch 12, CIFAR-10 Batch 3:  Validation Cost [1.5046378]
# Validation Accuracy [0.45459998]
# Epoch 12, CIFAR-10 Batch 4:  Validation Cost [1.4635689]
# Validation Accuracy [0.47639996]
# Epoch 12, CIFAR-10 Batch 5:  Validation Cost [1.5291851]
# Validation Accuracy [0.46499997]
# Epoch 13, CIFAR-10 Batch 1:  Validation Cost [1.4684927]
# Validation Accuracy [0.48379993]
# Epoch 13, CIFAR-10 Batch 2:  Validation Cost [1.5231053]
# Validation Accuracy [0.45499995]
# Epoch 13, CIFAR-10 Batch 3:  Validation Cost [1.4956076]
# Validation Accuracy [0.46119994]
# Epoch 13, CIFAR-10 Batch 4:  Validation Cost [1.4520231]
# Validation Accuracy [0.48439997]
# Epoch 13, CIFAR-10 Batch 5:  Validation Cost [1.4579886]
# Validation Accuracy [0.47659993]
# Epoch 14, CIFAR-10 Batch 1:  Validation Cost [1.4166036]
# Validation Accuracy [0.49159998]
# Epoch 14, CIFAR-10 Batch 2:  Validation Cost [1.4559051]
# Validation Accuracy [0.48159999]
# Epoch 14, CIFAR-10 Batch 3:  Validation Cost [1.4410291]
# Validation Accuracy [0.48659992]
# Epoch 14, CIFAR-10 Batch 4:  Validation Cost [1.4292574]
# Validation Accuracy [0.48299998]
# Epoch 14, CIFAR-10 Batch 5:  Validation Cost [1.5167589]
# Validation Accuracy [0.47040001]
# Epoch 15, CIFAR-10 Batch 1:  Validation Cost [1.4472303]
# Validation Accuracy [0.49459994]
# Epoch 15, CIFAR-10 Batch 2:  Validation Cost [1.447726]
# Validation Accuracy [0.49119997]
# Epoch 15, CIFAR-10 Batch 3:  Validation Cost [1.4911346]
# Validation Accuracy [0.47699997]
# Epoch 15, CIFAR-10 Batch 4:  Validation Cost [1.4500124]
# Validation Accuracy [0.49719995]
# Epoch 15, CIFAR-10 Batch 5:  Validation Cost [1.4387383]
# Validation Accuracy [0.48859996]
# Epoch 16, CIFAR-10 Batch 1:  Validation Cost [1.4098551]
# Validation Accuracy [0.49559993]
# Epoch 16, CIFAR-10 Batch 2:  Validation Cost [1.4462597]
# Validation Accuracy [0.48119998]
# Epoch 16, CIFAR-10 Batch 3:  Validation Cost [1.4291495]
# Validation Accuracy [0.48860002]
# Epoch 16, CIFAR-10 Batch 4:  Validation Cost [1.4020905]
# Validation Accuracy [0.50459993]
# Epoch 16, CIFAR-10 Batch 5:  Validation Cost [1.4250278]
# Validation Accuracy [0.49859995]
# Epoch 17, CIFAR-10 Batch 1:  Validation Cost [1.3984178]
# Validation Accuracy [0.50259995]
# Epoch 17, CIFAR-10 Batch 2:  Validation Cost [1.4256392]
# Validation Accuracy [0.50459993]
# Epoch 17, CIFAR-10 Batch 3:  Validation Cost [1.4145069]
# Validation Accuracy [0.48679996]
# Epoch 17, CIFAR-10 Batch 4:  Validation Cost [1.3754739]
# Validation Accuracy [0.50459993]
# Epoch 17, CIFAR-10 Batch 5:  Validation Cost [1.3915681]
# Validation Accuracy [0.50819993]
# Epoch 18, CIFAR-10 Batch 1:  Validation Cost [1.3634291]
# Validation Accuracy [0.51219994]
# Epoch 18, CIFAR-10 Batch 2:  Validation Cost [1.4214318]
# Validation Accuracy [0.49799997]
# Epoch 18, CIFAR-10 Batch 3:  Validation Cost [1.4291222]
# Validation Accuracy [0.48099995]
# Epoch 18, CIFAR-10 Batch 4:  Validation Cost [1.38132]
# Validation Accuracy [0.50699997]
# Epoch 18, CIFAR-10 Batch 5:  Validation Cost [1.373099]
# Validation Accuracy [0.50879991]
# Epoch 19, CIFAR-10 Batch 1:  Validation Cost [1.3464974]
# Validation Accuracy [0.5219999]
# Epoch 19, CIFAR-10 Batch 2:  Validation Cost [1.3845963]
# Validation Accuracy [0.5158]
# Epoch 19, CIFAR-10 Batch 3:  Validation Cost [1.3691134]
# Validation Accuracy [0.51019996]
# Epoch 19, CIFAR-10 Batch 4:  Validation Cost [1.4128917]
# Validation Accuracy [0.49879992]
# Epoch 19, CIFAR-10 Batch 5:  Validation Cost [1.355738]
# Validation Accuracy [0.52519995]
# Epoch 20, CIFAR-10 Batch 1:  Validation Cost [1.3736367]
# Validation Accuracy [0.51559997]
# Epoch 20, CIFAR-10 Batch 2:  Validation Cost [1.4225253]
# Validation Accuracy [0.50779992]
# Epoch 20, CIFAR-10 Batch 3:  Validation Cost [1.3890647]
# Validation Accuracy [0.505]
# Epoch 20, CIFAR-10 Batch 4:  Validation Cost [1.3591232]
# Validation Accuracy [0.51379991]
# Epoch 20, CIFAR-10 Batch 5:  Validation Cost [1.4027636]
# Validation Accuracy [0.5101999]
# Epoch 21, CIFAR-10 Batch 1:  Validation Cost [1.3391322]
# Validation Accuracy [0.53259993]
# Epoch 21, CIFAR-10 Batch 2:  Validation Cost [1.3467522]
# Validation Accuracy [0.51679993]
# Epoch 21, CIFAR-10 Batch 3:  Validation Cost [1.3514054]
# Validation Accuracy [0.52039993]
# Epoch 21, CIFAR-10 Batch 4:  Validation Cost [1.3821055]
# Validation Accuracy [0.49679995]
# Epoch 21, CIFAR-10 Batch 5:  Validation Cost [1.3450084]
# Validation Accuracy [0.52799994]
# Epoch 22, CIFAR-10 Batch 1:  Validation Cost [1.352248]
# Validation Accuracy [0.53659999]
# Epoch 22, CIFAR-10 Batch 2:  Validation Cost [1.3457843]
# Validation Accuracy [0.52479994]
# Epoch 22, CIFAR-10 Batch 3:  Validation Cost [1.3750895]
# Validation Accuracy [0.51499999]
# Epoch 22, CIFAR-10 Batch 4:  Validation Cost [1.3533289]
# Validation Accuracy [0.53559995]
# Epoch 22, CIFAR-10 Batch 5:  Validation Cost [1.3391547]
# Validation Accuracy [0.52319992]
# Epoch 23, CIFAR-10 Batch 1:  Validation Cost [1.3202701]
# Validation Accuracy [0.52919996]
# Epoch 23, CIFAR-10 Batch 2:  Validation Cost [1.3609406]
# Validation Accuracy [0.52519995]
# Epoch 23, CIFAR-10 Batch 3:  Validation Cost [1.3339598]
# Validation Accuracy [0.52599996]
# Epoch 23, CIFAR-10 Batch 4:  Validation Cost [1.3598847]
# Validation Accuracy [0.52439994]
# Epoch 23, CIFAR-10 Batch 5:  Validation Cost [1.3524525]
# Validation Accuracy [0.52559996]
# Epoch 24, CIFAR-10 Batch 1:  Validation Cost [1.3075529]
# Validation Accuracy [0.53600001]
# Epoch 24, CIFAR-10 Batch 2:  Validation Cost [1.3228426]
# Validation Accuracy [0.53179991]
# Epoch 24, CIFAR-10 Batch 3:  Validation Cost [1.3516876]
# Validation Accuracy [0.52239996]
# Epoch 24, CIFAR-10 Batch 4:  Validation Cost [1.3218129]
# Validation Accuracy [0.53039992]
# Epoch 24, CIFAR-10 Batch 5:  Validation Cost [1.3179511]
# Validation Accuracy [0.53379995]
# Epoch 25, CIFAR-10 Batch 1:  Validation Cost [1.2952837]
# Validation Accuracy [0.53679991]
# Epoch 25, CIFAR-10 Batch 2:  Validation Cost [1.3037059]
# Validation Accuracy [0.53659993]
# Epoch 25, CIFAR-10 Batch 3:  Validation Cost [1.3052239]
# Validation Accuracy [0.54039997]
# Epoch 25, CIFAR-10 Batch 4:  Validation Cost [1.3004107]
# Validation Accuracy [0.54199994]
# Epoch 25, CIFAR-10 Batch 5:  Validation Cost [1.2988478]
# Validation Accuracy [0.54019994]
# Epoch 26, CIFAR-10 Batch 1:  Validation Cost [1.3029869]
# Validation Accuracy [0.53859997]
# Epoch 26, CIFAR-10 Batch 2:  Validation Cost [1.3148142]
# Validation Accuracy [0.53479993]
# Epoch 26, CIFAR-10 Batch 3:  Validation Cost [1.3155727]
# Validation Accuracy [0.54019988]
# Epoch 26, CIFAR-10 Batch 4:  Validation Cost [1.2898225]
# Validation Accuracy [0.54599988]
# Epoch 26, CIFAR-10 Batch 5:  Validation Cost [1.2950428]
# Validation Accuracy [0.5503999]
# Epoch 27, CIFAR-10 Batch 1:  Validation Cost [1.2713767]
# Validation Accuracy [0.55679995]
# Epoch 27, CIFAR-10 Batch 2:  Validation Cost [1.2973031]
# Validation Accuracy [0.54119992]
# Epoch 27, CIFAR-10 Batch 3:  Validation Cost [1.3385446]
# Validation Accuracy [0.52959991]
# Epoch 27, CIFAR-10 Batch 4:  Validation Cost [1.3094066]
# Validation Accuracy [0.54479992]
# Epoch 27, CIFAR-10 Batch 5:  Validation Cost [1.2650518]
# Validation Accuracy [0.55379993]
# Epoch 28, CIFAR-10 Batch 1:  Validation Cost [1.2642235]
# Validation Accuracy [0.55759996]
# Epoch 28, CIFAR-10 Batch 2:  Validation Cost [1.2822948]
# Validation Accuracy [0.54119992]
# Epoch 28, CIFAR-10 Batch 3:  Validation Cost [1.3040459]
# Validation Accuracy [0.54099995]
# Epoch 28, CIFAR-10 Batch 4:  Validation Cost [1.2784991]
# Validation Accuracy [0.54979992]
# Epoch 28, CIFAR-10 Batch 5:  Validation Cost [1.2713946]
# Validation Accuracy [0.55479997]
# Epoch 29, CIFAR-10 Batch 1:  Validation Cost [1.2594491]
# Validation Accuracy [0.56599998]
# Epoch 29, CIFAR-10 Batch 2:  Validation Cost [1.2827672]
# Validation Accuracy [0.53979993]
# Epoch 29, CIFAR-10 Batch 3:  Validation Cost [1.3027132]
# Validation Accuracy [0.54939997]
# Epoch 29, CIFAR-10 Batch 4:  Validation Cost [1.2897546]
# Validation Accuracy [0.54680002]
# Epoch 29, CIFAR-10 Batch 5:  Validation Cost [1.2716876]
# Validation Accuracy [0.55599993]
# Epoch 30, CIFAR-10 Batch 1:  Validation Cost [1.2959836]
# Validation Accuracy [0.54259992]
# Epoch 30, CIFAR-10 Batch 2:  Validation Cost [1.2733901]
# Validation Accuracy [0.54699993]
# Epoch 30, CIFAR-10 Batch 3:  Validation Cost [1.2943177]
# Validation Accuracy [0.54979992]
# Epoch 30, CIFAR-10 Batch 4:  Validation Cost [1.2478012]
# Validation Accuracy [0.55899996]
# Epoch 30, CIFAR-10 Batch 5:  Validation Cost [1.2966433]
# Validation Accuracy [0.54979992]
# Epoch 31, CIFAR-10 Batch 1:  Validation Cost [1.2742256]
# Validation Accuracy [0.54999989]
# Epoch 31, CIFAR-10 Batch 2:  Validation Cost [1.2522618]
# Validation Accuracy [0.55639994]
# Epoch 31, CIFAR-10 Batch 3:  Validation Cost [1.2979597]
# Validation Accuracy [0.53859991]
# Epoch 31, CIFAR-10 Batch 4:  Validation Cost [1.2896556]
# Validation Accuracy [0.54919994]
# Epoch 31, CIFAR-10 Batch 5:  Validation Cost [1.2796308]
# Validation Accuracy [0.56519991]
# Epoch 32, CIFAR-10 Batch 1:  Validation Cost [1.2466404]
# Validation Accuracy [0.56739992]
# Epoch 32, CIFAR-10 Batch 2:  Validation Cost [1.2516968]
# Validation Accuracy [0.56539994]
# Epoch 32, CIFAR-10 Batch 3:  Validation Cost [1.2486403]
# Validation Accuracy [0.56279993]
# Epoch 32, CIFAR-10 Batch 4:  Validation Cost [1.2389766]
# Validation Accuracy [0.56499994]
# Epoch 32, CIFAR-10 Batch 5:  Validation Cost [1.2567261]
# Validation Accuracy [0.5589999]
# Epoch 33, CIFAR-10 Batch 1:  Validation Cost [1.2449002]
# Validation Accuracy [0.5611999]
# Epoch 33, CIFAR-10 Batch 2:  Validation Cost [1.2622507]
# Validation Accuracy [0.5647999]
# Epoch 33, CIFAR-10 Batch 3:  Validation Cost [1.2698834]
# Validation Accuracy [0.55619997]
# Epoch 33, CIFAR-10 Batch 4:  Validation Cost [1.2417533]
# Validation Accuracy [0.57379997]
# Epoch 33, CIFAR-10 Batch 5:  Validation Cost [1.2398015]
# Validation Accuracy [0.5733999]
# Epoch 34, CIFAR-10 Batch 1:  Validation Cost [1.2179329]
# Validation Accuracy [0.57999992]
# Epoch 34, CIFAR-10 Batch 2:  Validation Cost [1.2450546]
# Validation Accuracy [0.55619991]
# Epoch 34, CIFAR-10 Batch 3:  Validation Cost [1.2509617]
# Validation Accuracy [0.57119989]
# Epoch 34, CIFAR-10 Batch 4:  Validation Cost [1.2479267]
# Validation Accuracy [0.56719989]
# Epoch 34, CIFAR-10 Batch 5:  Validation Cost [1.2587918]
# Validation Accuracy [0.55619991]
# Epoch 35, CIFAR-10 Batch 1:  Validation Cost [1.2615442]
# Validation Accuracy [0.55639994]
# Epoch 35, CIFAR-10 Batch 2:  Validation Cost [1.2210971]
# Validation Accuracy [0.57739997]
# Epoch 35, CIFAR-10 Batch 3:  Validation Cost [1.2850533]
# Validation Accuracy [0.55139995]
# Epoch 35, CIFAR-10 Batch 4:  Validation Cost [1.2258763]
# Validation Accuracy [0.56839991]
# Epoch 35, CIFAR-10 Batch 5:  Validation Cost [1.2543288]
# Validation Accuracy [0.56479996]
# Epoch 36, CIFAR-10 Batch 1:  Validation Cost [1.2321975]
# Validation Accuracy [0.57699996]
# Epoch 36, CIFAR-10 Batch 2:  Validation Cost [1.2344488]
# Validation Accuracy [0.57219988]
# Epoch 36, CIFAR-10 Batch 3:  Validation Cost [1.24773]
# Validation Accuracy [0.56379992]
# Epoch 36, CIFAR-10 Batch 4:  Validation Cost [1.2229114]
# Validation Accuracy [0.57719994]
# Epoch 36, CIFAR-10 Batch 5:  Validation Cost [1.2081209]
# Validation Accuracy [0.57199991]
# Epoch 37, CIFAR-10 Batch 1:  Validation Cost [1.2144182]
# Validation Accuracy [0.57539994]
# Epoch 37, CIFAR-10 Batch 2:  Validation Cost [1.196696]
# Validation Accuracy [0.58279991]
# Epoch 37, CIFAR-10 Batch 3:  Validation Cost [1.2411634]
# Validation Accuracy [0.57259989]
# Epoch 37, CIFAR-10 Batch 4:  Validation Cost [1.2328684]
# Validation Accuracy [0.57459998]
# Epoch 37, CIFAR-10 Batch 5:  Validation Cost [1.2179154]
# Validation Accuracy [0.58219993]
# Epoch 38, CIFAR-10 Batch 1:  Validation Cost [1.2295816]
# Validation Accuracy [0.56759995]
# Epoch 38, CIFAR-10 Batch 2:  Validation Cost [1.204035]
# Validation Accuracy [0.58359993]
# Epoch 38, CIFAR-10 Batch 3:  Validation Cost [1.2254446]
# Validation Accuracy [0.56119996]
# Epoch 38, CIFAR-10 Batch 4:  Validation Cost [1.2088939]
# Validation Accuracy [0.58479989]
# Epoch 38, CIFAR-10 Batch 5:  Validation Cost [1.2886121]
# Validation Accuracy [0.55999994]
# Epoch 39, CIFAR-10 Batch 1:  Validation Cost [1.2303879]
# Validation Accuracy [0.5769999]
# Epoch 39, CIFAR-10 Batch 2:  Validation Cost [1.2017813]
# Validation Accuracy [0.58499992]
# Epoch 39, CIFAR-10 Batch 3:  Validation Cost [1.1970369]
# Validation Accuracy [0.5819999]
# Epoch 39, CIFAR-10 Batch 4:  Validation Cost [1.2269604]
# Validation Accuracy [0.58399993]
# Epoch 39, CIFAR-10 Batch 5:  Validation Cost [1.2224159]
# Validation Accuracy [0.57899994]
# Epoch 40, CIFAR-10 Batch 1:  Validation Cost [1.2474831]
# Validation Accuracy [0.5589999]
# Epoch 40, CIFAR-10 Batch 2:  Validation Cost [1.2150079]
# Validation Accuracy [0.57859993]
# Epoch 40, CIFAR-10 Batch 3:  Validation Cost [1.2321527]
# Validation Accuracy [0.56879991]
# Epoch 40, CIFAR-10 Batch 4:  Validation Cost [1.2061756]
# Validation Accuracy [0.57759988]
# Epoch 40, CIFAR-10 Batch 5:  Validation Cost [1.197626]
# Validation Accuracy [0.58679992]
# Epoch 41, CIFAR-10 Batch 1:  Validation Cost [1.2201668]
# Validation Accuracy [0.58279991]
# Epoch 41, CIFAR-10 Batch 2:  Validation Cost [1.1865711]
# Validation Accuracy [0.5898]
# Epoch 41, CIFAR-10 Batch 3:  Validation Cost [1.2096097]
# Validation Accuracy [0.57379991]
# Epoch 41, CIFAR-10 Batch 4:  Validation Cost [1.2031881]
# Validation Accuracy [0.59099984]
# Epoch 41, CIFAR-10 Batch 5:  Validation Cost [1.2208985]
# Validation Accuracy [0.5747999]
# Epoch 42, CIFAR-10 Batch 1:  Validation Cost [1.2251847]
# Validation Accuracy [0.56939995]
# Epoch 42, CIFAR-10 Batch 2:  Validation Cost [1.1937909]
# Validation Accuracy [0.58819997]
# Epoch 42, CIFAR-10 Batch 3:  Validation Cost [1.2085413]
# Validation Accuracy [0.57379991]
# Epoch 42, CIFAR-10 Batch 4:  Validation Cost [1.221936]
# Validation Accuracy [0.56939989]
# Epoch 42, CIFAR-10 Batch 5:  Validation Cost [1.1871933]
# Validation Accuracy [0.59119993]
# Epoch 43, CIFAR-10 Batch 1:  Validation Cost [1.1790786]
# Validation Accuracy [0.58339989]
# Epoch 43, CIFAR-10 Batch 2:  Validation Cost [1.2021933]
# Validation Accuracy [0.57299995]
# Epoch 43, CIFAR-10 Batch 3:  Validation Cost [1.1966723]
# Validation Accuracy [0.5661999]
# Epoch 43, CIFAR-10 Batch 4:  Validation Cost [1.1908144]
# Validation Accuracy [0.58539993]
# Epoch 43, CIFAR-10 Batch 5:  Validation Cost [1.2024013]
# Validation Accuracy [0.59459984]
# Epoch 44, CIFAR-10 Batch 1:  Validation Cost [1.1817966]
# Validation Accuracy [0.58939993]
# Epoch 44, CIFAR-10 Batch 2:  Validation Cost [1.1755415]
# Validation Accuracy [0.58579993]
# Epoch 44, CIFAR-10 Batch 3:  Validation Cost [1.1913625]
# Validation Accuracy [0.58719987]
# Epoch 44, CIFAR-10 Batch 4:  Validation Cost [1.2120397]
# Validation Accuracy [0.58839995]
# Epoch 44, CIFAR-10 Batch 5:  Validation Cost [1.169054]
# Validation Accuracy [0.60279995]
# Epoch 45, CIFAR-10 Batch 1:  Validation Cost [1.174859]
# Validation Accuracy [0.58699989]
# Epoch 45, CIFAR-10 Batch 2:  Validation Cost [1.1876441]
# Validation Accuracy [0.59019995]
# Epoch 45, CIFAR-10 Batch 3:  Validation Cost [1.1754043]
# Validation Accuracy [0.58999997]
# Epoch 45, CIFAR-10 Batch 4:  Validation Cost [1.1752028]
# Validation Accuracy [0.59599996]
# Epoch 45, CIFAR-10 Batch 5:  Validation Cost [1.171556]
# Validation Accuracy [0.59679991]
# Epoch 46, CIFAR-10 Batch 1:  Validation Cost [1.1506262]
# Validation Accuracy [0.60539991]
# Epoch 46, CIFAR-10 Batch 2:  Validation Cost [1.1831561]
# Validation Accuracy [0.59519994]
# Epoch 46, CIFAR-10 Batch 3:  Validation Cost [1.1766576]
# Validation Accuracy [0.58999991]
# Epoch 46, CIFAR-10 Batch 4:  Validation Cost [1.182718]
# Validation Accuracy [0.60099989]
# Epoch 46, CIFAR-10 Batch 5:  Validation Cost [1.1599245]
# Validation Accuracy [0.59179991]
# Epoch 47, CIFAR-10 Batch 1:  Validation Cost [1.1648833]
# Validation Accuracy [0.59479994]
# Epoch 47, CIFAR-10 Batch 2:  Validation Cost [1.1719844]
# Validation Accuracy [0.58419991]
# Epoch 47, CIFAR-10 Batch 3:  Validation Cost [1.201112]
# Validation Accuracy [0.58479995]
# Epoch 47, CIFAR-10 Batch 4:  Validation Cost [1.1634357]
# Validation Accuracy [0.59659994]
# Epoch 47, CIFAR-10 Batch 5:  Validation Cost [1.175665]
# Validation Accuracy [0.59839994]
# Epoch 48, CIFAR-10 Batch 1:  Validation Cost [1.1776335]
# Validation Accuracy [0.59199989]
# Epoch 48, CIFAR-10 Batch 2:  Validation Cost [1.1567324]
# Validation Accuracy [0.59779996]
# Epoch 48, CIFAR-10 Batch 3:  Validation Cost [1.1917895]
# Validation Accuracy [0.59159994]
# Epoch 48, CIFAR-10 Batch 4:  Validation Cost [1.1654012]
# Validation Accuracy [0.59359992]
# Epoch 48, CIFAR-10 Batch 5:  Validation Cost [1.2146994]
# Validation Accuracy [0.58579993]
# Epoch 49, CIFAR-10 Batch 1:  Validation Cost [1.1816664]
# Validation Accuracy [0.59939992]
# Epoch 49, CIFAR-10 Batch 2:  Validation Cost [1.1566564]
# Validation Accuracy [0.59859991]
# Epoch 49, CIFAR-10 Batch 3:  Validation Cost [1.1722168]
# Validation Accuracy [0.60359991]
# Epoch 49, CIFAR-10 Batch 4:  Validation Cost [1.1863868]
# Validation Accuracy [0.59579992]
# Epoch 49, CIFAR-10 Batch 5:  Validation Cost [1.1375618]
# Validation Accuracy [0.61199987]
# Epoch 50, CIFAR-10 Batch 1:  Validation Cost [1.1667986]
# Validation Accuracy [0.60419989]
# Epoch 50, CIFAR-10 Batch 2:  Validation Cost [1.1638225]
# Validation Accuracy [0.59819996]
# Epoch 50, CIFAR-10 Batch 3:  Validation Cost [1.1808286]
# Validation Accuracy [0.59359992]
# Epoch 50, CIFAR-10 Batch 4:  Validation Cost [1.138822]
# Validation Accuracy [0.60419989]
# Epoch 50, CIFAR-10 Batch 5:  Validation Cost [1.1619575]
# Validation Accuracy [0.60459989]
# Epoch 51, CIFAR-10 Batch 1:  Validation Cost [1.1443685]
# Validation Accuracy [0.60539997]
# Epoch 51, CIFAR-10 Batch 2:  Validation Cost [1.1463557]
# Validation Accuracy [0.60399991]
# Epoch 51, CIFAR-10 Batch 3:  Validation Cost [1.1550732]
# Validation Accuracy [0.60499996]
# Epoch 51, CIFAR-10 Batch 4:  Validation Cost [1.1474197]
# Validation Accuracy [0.6103999]
# Epoch 51, CIFAR-10 Batch 5:  Validation Cost [1.1769322]
# Validation Accuracy [0.59399998]
# Epoch 52, CIFAR-10 Batch 1:  Validation Cost [1.1514051]
# Validation Accuracy [0.60659993]
# Epoch 52, CIFAR-10 Batch 2:  Validation Cost [1.1283116]
# Validation Accuracy [0.61259991]
# Epoch 52, CIFAR-10 Batch 3:  Validation Cost [1.1474591]
# Validation Accuracy [0.60959995]
# Epoch 52, CIFAR-10 Batch 4:  Validation Cost [1.1396824]
# Validation Accuracy [0.60759997]
# Epoch 52, CIFAR-10 Batch 5:  Validation Cost [1.1546435]
# Validation Accuracy [0.61119986]
# Epoch 53, CIFAR-10 Batch 1:  Validation Cost [1.1374829]
# Validation Accuracy [0.60619992]
# Epoch 53, CIFAR-10 Batch 2:  Validation Cost [1.1447634]
# Validation Accuracy [0.60179991]
# Epoch 53, CIFAR-10 Batch 3:  Validation Cost [1.177107]
# Validation Accuracy [0.59039998]
# Epoch 53, CIFAR-10 Batch 4:  Validation Cost [1.1359274]
# Validation Accuracy [0.61479992]
# Epoch 53, CIFAR-10 Batch 5:  Validation Cost [1.1630393]
# Validation Accuracy [0.60879987]
# Epoch 54, CIFAR-10 Batch 1:  Validation Cost [1.1368279]
# Validation Accuracy [0.60359985]
# Epoch 54, CIFAR-10 Batch 2:  Validation Cost [1.146251]
# Validation Accuracy [0.59899992]
# Epoch 54, CIFAR-10 Batch 3:  Validation Cost [1.1310498]
# Validation Accuracy [0.60939991]
# Epoch 54, CIFAR-10 Batch 4:  Validation Cost [1.1466348]
# Validation Accuracy [0.60579991]
# Epoch 54, CIFAR-10 Batch 5:  Validation Cost [1.1923748]
# Validation Accuracy [0.5941999]
# Epoch 55, CIFAR-10 Batch 1:  Validation Cost [1.1387819]
# Validation Accuracy [0.60199988]
# Epoch 55, CIFAR-10 Batch 2:  Validation Cost [1.1184775]
# Validation Accuracy [0.61659992]
# Epoch 55, CIFAR-10 Batch 3:  Validation Cost [1.1553407]
# Validation Accuracy [0.59699988]
# Epoch 55, CIFAR-10 Batch 4:  Validation Cost [1.1318386]
# Validation Accuracy [0.61859989]
# Epoch 55, CIFAR-10 Batch 5:  Validation Cost [1.1222614]
# Validation Accuracy [0.60779983]
# Epoch 56, CIFAR-10 Batch 1:  Validation Cost [1.1356184]
# Validation Accuracy [0.60439986]
# Epoch 56, CIFAR-10 Batch 2:  Validation Cost [1.1561779]
# Validation Accuracy [0.59339994]
# Epoch 56, CIFAR-10 Batch 3:  Validation Cost [1.1671464]
# Validation Accuracy [0.60359991]
# Epoch 56, CIFAR-10 Batch 4:  Validation Cost [1.1499742]
# Validation Accuracy [0.60079992]
# Epoch 56, CIFAR-10 Batch 5:  Validation Cost [1.1579489]
# Validation Accuracy [0.60759991]
# Epoch 57, CIFAR-10 Batch 1:  Validation Cost [1.1693947]
# Validation Accuracy [0.60059994]
# Epoch 57, CIFAR-10 Batch 2:  Validation Cost [1.1202244]
# Validation Accuracy [0.61499995]
# Epoch 57, CIFAR-10 Batch 3:  Validation Cost [1.1524458]
# Validation Accuracy [0.5999999]
# Epoch 57, CIFAR-10 Batch 4:  Validation Cost [1.1867279]
# Validation Accuracy [0.5999999]
# Epoch 57, CIFAR-10 Batch 5:  Validation Cost [1.1327816]
# Validation Accuracy [0.61019993]
# Epoch 58, CIFAR-10 Batch 1:  Validation Cost [1.1349058]
# Validation Accuracy [0.62139988]
# Epoch 58, CIFAR-10 Batch 2:  Validation Cost [1.1407077]
# Validation Accuracy [0.60559988]
# Epoch 58, CIFAR-10 Batch 3:  Validation Cost [1.1796416]
# Validation Accuracy [0.59299994]
# Epoch 58, CIFAR-10 Batch 4:  Validation Cost [1.1222265]
# Validation Accuracy [0.6157999]
# Epoch 58, CIFAR-10 Batch 5:  Validation Cost [1.1753632]
# Validation Accuracy [0.60099989]
# Epoch 59, CIFAR-10 Batch 1:  Validation Cost [1.1368896]
# Validation Accuracy [0.60619992]
# Epoch 59, CIFAR-10 Batch 2:  Validation Cost [1.1437172]
# Validation Accuracy [0.60559994]
# Epoch 59, CIFAR-10 Batch 3:  Validation Cost [1.1308095]
# Validation Accuracy [0.60819989]
# Epoch 59, CIFAR-10 Batch 4:  Validation Cost [1.1304824]
# Validation Accuracy [0.61379993]
# Epoch 59, CIFAR-10 Batch 5:  Validation Cost [1.1348834]
# Validation Accuracy [0.60799986]
# Epoch 60, CIFAR-10 Batch 1:  Validation Cost [1.13428]
# Validation Accuracy [0.60719985]
# Epoch 60, CIFAR-10 Batch 2:  Validation Cost [1.1153772]
# Validation Accuracy [0.61639988]
# Epoch 60, CIFAR-10 Batch 3:  Validation Cost [1.1398286]
# Validation Accuracy [0.5995999]
# Epoch 60, CIFAR-10 Batch 4:  Validation Cost [1.1481062]
# Validation Accuracy [0.61319995]
# Epoch 60, CIFAR-10 Batch 5:  Validation Cost [1.1503348]
# Validation Accuracy [0.60579985]
# Epoch 61, CIFAR-10 Batch 1:  Validation Cost [1.1235881]
# Validation Accuracy [0.61519992]
# Epoch 61, CIFAR-10 Batch 2:  Validation Cost [1.1226327]
# Validation Accuracy [0.60639989]
# Epoch 61, CIFAR-10 Batch 3:  Validation Cost [1.1614873]
# Validation Accuracy [0.5977999]
# Epoch 61, CIFAR-10 Batch 4:  Validation Cost [1.1172189]
# Validation Accuracy [0.61559987]
# Epoch 61, CIFAR-10 Batch 5:  Validation Cost [1.1641808]
# Validation Accuracy [0.61059999]
# Epoch 62, CIFAR-10 Batch 1:  Validation Cost [1.1116179]
# Validation Accuracy [0.61559987]
# Epoch 62, CIFAR-10 Batch 2:  Validation Cost [1.1213813]
# Validation Accuracy [0.6139999]
# Epoch 62, CIFAR-10 Batch 3:  Validation Cost [1.1244943]
# Validation Accuracy [0.60659993]
# Epoch 62, CIFAR-10 Batch 4:  Validation Cost [1.1057281]
# Validation Accuracy [0.61979991]
# Epoch 62, CIFAR-10 Batch 5:  Validation Cost [1.1179585]
# Validation Accuracy [0.61759996]
# Epoch 63, CIFAR-10 Batch 1:  Validation Cost [1.09635]
# Validation Accuracy [0.62699991]
# Epoch 63, CIFAR-10 Batch 2:  Validation Cost [1.1663933]
# Validation Accuracy [0.60299993]
# Epoch 63, CIFAR-10 Batch 3:  Validation Cost [1.1728655]
# Validation Accuracy [0.60219991]
# Epoch 63, CIFAR-10 Batch 4:  Validation Cost [1.1097124]
# Validation Accuracy [0.61519986]
# Epoch 63, CIFAR-10 Batch 5:  Validation Cost [1.1090038]
# Validation Accuracy [0.62019992]
# Epoch 64, CIFAR-10 Batch 1:  Validation Cost [1.0849627]
# Validation Accuracy [0.6225999]
# Epoch 64, CIFAR-10 Batch 2:  Validation Cost [1.1117823]
# Validation Accuracy [0.62339991]
# Epoch 64, CIFAR-10 Batch 3:  Validation Cost [1.1354148]
# Validation Accuracy [0.60659993]
# Epoch 64, CIFAR-10 Batch 4:  Validation Cost [1.1109605]
# Validation Accuracy [0.62019992]
# Epoch 64, CIFAR-10 Batch 5:  Validation Cost [1.114748]
# Validation Accuracy [0.61859989]
# Epoch 65, CIFAR-10 Batch 1:  Validation Cost [1.1195332]
# Validation Accuracy [0.61139989]
# Epoch 65, CIFAR-10 Batch 2:  Validation Cost [1.0848709]
# Validation Accuracy [0.62579989]
# Epoch 65, CIFAR-10 Batch 3:  Validation Cost [1.102855]
# Validation Accuracy [0.6207999]
# Epoch 65, CIFAR-10 Batch 4:  Validation Cost [1.1232641]
# Validation Accuracy [0.61899984]
# Epoch 65, CIFAR-10 Batch 5:  Validation Cost [1.1163254]
# Validation Accuracy [0.61979985]
# Epoch 66, CIFAR-10 Batch 1:  Validation Cost [1.1017711]
# Validation Accuracy [0.62759984]
# Epoch 66, CIFAR-10 Batch 2:  Validation Cost [1.099839]
# Validation Accuracy [0.61799991]
# Epoch 66, CIFAR-10 Batch 3:  Validation Cost [1.1185088]
# Validation Accuracy [0.61999989]
# Epoch 66, CIFAR-10 Batch 4:  Validation Cost [1.0874536]
# Validation Accuracy [0.62159991]
# Epoch 66, CIFAR-10 Batch 5:  Validation Cost [1.123087]
# Validation Accuracy [0.61859989]
# Epoch 67, CIFAR-10 Batch 1:  Validation Cost [1.1061481]
# Validation Accuracy [0.62239993]
# Epoch 67, CIFAR-10 Batch 2:  Validation Cost [1.0965148]
# Validation Accuracy [0.62119991]
# Epoch 67, CIFAR-10 Batch 3:  Validation Cost [1.1057479]
# Validation Accuracy [0.62219989]
# Epoch 67, CIFAR-10 Batch 4:  Validation Cost [1.1008329]
# Validation Accuracy [0.62719983]
# Epoch 67, CIFAR-10 Batch 5:  Validation Cost [1.1208198]
# Validation Accuracy [0.6275999]
# Epoch 68, CIFAR-10 Batch 1:  Validation Cost [1.1037959]
# Validation Accuracy [0.61879992]
# Epoch 68, CIFAR-10 Batch 2:  Validation Cost [1.1090335]
# Validation Accuracy [0.61819988]
# Epoch 68, CIFAR-10 Batch 3:  Validation Cost [1.1312267]
# Validation Accuracy [0.6085999]
# Epoch 68, CIFAR-10 Batch 4:  Validation Cost [1.1092445]
# Validation Accuracy [0.6243999]
# Epoch 68, CIFAR-10 Batch 5:  Validation Cost [1.1082089]
# Validation Accuracy [0.62339991]
# Epoch 69, CIFAR-10 Batch 1:  Validation Cost [1.119375]
# Validation Accuracy [0.60919988]
# Epoch 69, CIFAR-10 Batch 2:  Validation Cost [1.0944138]
# Validation Accuracy [0.6243999]
# Epoch 69, CIFAR-10 Batch 3:  Validation Cost [1.1356498]
# Validation Accuracy [0.60739994]
# Epoch 69, CIFAR-10 Batch 4:  Validation Cost [1.1154063]
# Validation Accuracy [0.62039989]
# Epoch 69, CIFAR-10 Batch 5:  Validation Cost [1.1362584]
# Validation Accuracy [0.61779988]
# Epoch 70, CIFAR-10 Batch 1:  Validation Cost [1.0786982]
# Validation Accuracy [0.62959993]
# Epoch 70, CIFAR-10 Batch 2:  Validation Cost [1.0798922]
# Validation Accuracy [0.63019991]
# Epoch 70, CIFAR-10 Batch 3:  Validation Cost [1.1101394]
# Validation Accuracy [0.62179995]
# Epoch 70, CIFAR-10 Batch 4:  Validation Cost [1.0962824]
# Validation Accuracy [0.62299991]
# Epoch 70, CIFAR-10 Batch 5:  Validation Cost [1.1053475]
# Validation Accuracy [0.61939991]
# Epoch 71, CIFAR-10 Batch 1:  Validation Cost [1.0855904]
# Validation Accuracy [0.62859988]
# Epoch 71, CIFAR-10 Batch 2:  Validation Cost [1.0886068]
# Validation Accuracy [0.61959994]
# Epoch 71, CIFAR-10 Batch 3:  Validation Cost [1.1475552]
# Validation Accuracy [0.60519993]
# Epoch 71, CIFAR-10 Batch 4:  Validation Cost [1.0830216]
# Validation Accuracy [0.62379986]
# Epoch 71, CIFAR-10 Batch 5:  Validation Cost [1.1105632]
# Validation Accuracy [0.62279993]
# Epoch 72, CIFAR-10 Batch 1:  Validation Cost [1.0784627]
# Validation Accuracy [0.62259984]
# Epoch 72, CIFAR-10 Batch 2:  Validation Cost [1.0888573]
# Validation Accuracy [0.62099993]
# Epoch 72, CIFAR-10 Batch 3:  Validation Cost [1.0964149]
# Validation Accuracy [0.62079984]
# Epoch 72, CIFAR-10 Batch 4:  Validation Cost [1.0857549]
# Validation Accuracy [0.62859988]
# Epoch 72, CIFAR-10 Batch 5:  Validation Cost [1.0878639]
# Validation Accuracy [0.63219988]
# Epoch 73, CIFAR-10 Batch 1:  Validation Cost [1.0748452]
# Validation Accuracy [0.6347999]
# Epoch 73, CIFAR-10 Batch 2:  Validation Cost [1.0923519]
# Validation Accuracy [0.61879992]
# Epoch 73, CIFAR-10 Batch 3:  Validation Cost [1.1584504]
# Validation Accuracy [0.5999999]
# Epoch 73, CIFAR-10 Batch 4:  Validation Cost [1.1059911]
# Validation Accuracy [0.6261999]
# Epoch 73, CIFAR-10 Batch 5:  Validation Cost [1.1013905]
# Validation Accuracy [0.6311999]
# Epoch 74, CIFAR-10 Batch 1:  Validation Cost [1.0821325]
# Validation Accuracy [0.63019991]
# Epoch 74, CIFAR-10 Batch 2:  Validation Cost [1.100848]
# Validation Accuracy [0.63039988]
# Epoch 74, CIFAR-10 Batch 3:  Validation Cost [1.119519]
# Validation Accuracy [0.61059988]
# Epoch 74, CIFAR-10 Batch 4:  Validation Cost [1.0816597]
# Validation Accuracy [0.63599986]
# Epoch 74, CIFAR-10 Batch 5:  Validation Cost [1.0664821]
# Validation Accuracy [0.63999987]
# Epoch 75, CIFAR-10 Batch 1:  Validation Cost [1.1088732]
# Validation Accuracy [0.6243999]
# Epoch 75, CIFAR-10 Batch 2:  Validation Cost [1.092589]
# Validation Accuracy [0.62339985]
# Epoch 75, CIFAR-10 Batch 3:  Validation Cost [1.0928874]
# Validation Accuracy [0.62319988]
# Epoch 75, CIFAR-10 Batch 4:  Validation Cost [1.0854198]
# Validation Accuracy [0.62279987]
# Epoch 75, CIFAR-10 Batch 5:  Validation Cost [1.0729614]
# Validation Accuracy [0.64639986]
# Epoch 76, CIFAR-10 Batch 1:  Validation Cost [1.110324]
# Validation Accuracy [0.61639988]
# Epoch 76, CIFAR-10 Batch 2:  Validation Cost [1.0792649]
# Validation Accuracy [0.62359989]
# Epoch 76, CIFAR-10 Batch 3:  Validation Cost [1.0858268]
# Validation Accuracy [0.6275999]
# Epoch 76, CIFAR-10 Batch 4:  Validation Cost [1.0659343]
# Validation Accuracy [0.64159995]
# Epoch 76, CIFAR-10 Batch 5:  Validation Cost [1.0600927]
# Validation Accuracy [0.63439989]
# Epoch 77, CIFAR-10 Batch 1:  Validation Cost [1.0636501]
# Validation Accuracy [0.63419986]
# Epoch 77, CIFAR-10 Batch 2:  Validation Cost [1.0832939]
# Validation Accuracy [0.6293999]
# Epoch 77, CIFAR-10 Batch 3:  Validation Cost [1.0946212]
# Validation Accuracy [0.62379992]
# Epoch 77, CIFAR-10 Batch 4:  Validation Cost [1.1093736]
# Validation Accuracy [0.62779993]
# Epoch 77, CIFAR-10 Batch 5:  Validation Cost [1.0688586]
# Validation Accuracy [0.63399994]
# Epoch 78, CIFAR-10 Batch 1:  Validation Cost [1.1031368]
# Validation Accuracy [0.62779993]
# Epoch 78, CIFAR-10 Batch 2:  Validation Cost [1.1012356]
# Validation Accuracy [0.62239993]
# Epoch 78, CIFAR-10 Batch 3:  Validation Cost [1.1054877]
# Validation Accuracy [0.61779994]
# Epoch 78, CIFAR-10 Batch 4:  Validation Cost [1.0564811]
# Validation Accuracy [0.64499992]
# Epoch 78, CIFAR-10 Batch 5:  Validation Cost [1.1340599]
# Validation Accuracy [0.62199986]
# Epoch 79, CIFAR-10 Batch 1:  Validation Cost [1.0680629]
# Validation Accuracy [0.6311999]
# Epoch 79, CIFAR-10 Batch 2:  Validation Cost [1.0574608]
# Validation Accuracy [0.64439988]
# Epoch 79, CIFAR-10 Batch 3:  Validation Cost [1.0909228]
# Validation Accuracy [0.63619989]
# Epoch 79, CIFAR-10 Batch 4:  Validation Cost [1.0807345]
# Validation Accuracy [0.63779992]
# Epoch 79, CIFAR-10 Batch 5:  Validation Cost [1.0847588]
# Validation Accuracy [0.62579989]
# Epoch 80, CIFAR-10 Batch 1:  Validation Cost [1.0786797]
# Validation Accuracy [0.62479991]
# Epoch 80, CIFAR-10 Batch 2:  Validation Cost [1.0688636]
# Validation Accuracy [0.62679994]
# Epoch 80, CIFAR-10 Batch 3:  Validation Cost [1.103814]
# Validation Accuracy [0.61779988]
# Epoch 80, CIFAR-10 Batch 4:  Validation Cost [1.0895338]
# Validation Accuracy [0.62599993]
# Epoch 80, CIFAR-10 Batch 5:  Validation Cost [1.0605892]
# Validation Accuracy [0.63599986]
# Epoch 81, CIFAR-10 Batch 1:  Validation Cost [1.0594102]
# Validation Accuracy [0.63559985]
# Epoch 81, CIFAR-10 Batch 2:  Validation Cost [1.0924453]
# Validation Accuracy [0.62579989]
# Epoch 81, CIFAR-10 Batch 3:  Validation Cost [1.0821433]
# Validation Accuracy [0.63219988]
# Epoch 81, CIFAR-10 Batch 4:  Validation Cost [1.0493212]
# Validation Accuracy [0.64519989]
# Epoch 81, CIFAR-10 Batch 5:  Validation Cost [1.0984728]
# Validation Accuracy [0.62059993]
# Epoch 82, CIFAR-10 Batch 1:  Validation Cost [1.0720444]
# Validation Accuracy [0.63799989]
# Epoch 82, CIFAR-10 Batch 2:  Validation Cost [1.1032681]
# Validation Accuracy [0.62779993]
# Epoch 82, CIFAR-10 Batch 3:  Validation Cost [1.1067257]
# Validation Accuracy [0.61619985]
# Epoch 82, CIFAR-10 Batch 4:  Validation Cost [1.0711128]
# Validation Accuracy [0.6365999]
# Epoch 82, CIFAR-10 Batch 5:  Validation Cost [1.1073701]
# Validation Accuracy [0.62379992]
# Epoch 83, CIFAR-10 Batch 1:  Validation Cost [1.0727385]
# Validation Accuracy [0.63499987]
# Epoch 83, CIFAR-10 Batch 2:  Validation Cost [1.0793579]
# Validation Accuracy [0.61919993]
# Epoch 83, CIFAR-10 Batch 3:  Validation Cost [1.0824221]
# Validation Accuracy [0.62899995]
# Epoch 83, CIFAR-10 Batch 4:  Validation Cost [1.1035312]
# Validation Accuracy [0.61379987]
# Epoch 83, CIFAR-10 Batch 5:  Validation Cost [1.0626705]
# Validation Accuracy [0.64059985]
# Epoch 84, CIFAR-10 Batch 1:  Validation Cost [1.076094]
# Validation Accuracy [0.63759989]
# Epoch 84, CIFAR-10 Batch 2:  Validation Cost [1.0586566]
# Validation Accuracy [0.63319993]
# Epoch 84, CIFAR-10 Batch 3:  Validation Cost [1.0705925]
# Validation Accuracy [0.62719995]
# Epoch 84, CIFAR-10 Batch 4:  Validation Cost [1.0643911]
# Validation Accuracy [0.63919991]
# Epoch 84, CIFAR-10 Batch 5:  Validation Cost [1.0730121]
# Validation Accuracy [0.63439989]
# Epoch 85, CIFAR-10 Batch 1:  Validation Cost [1.0639729]
# Validation Accuracy [0.63319987]
# Epoch 85, CIFAR-10 Batch 2:  Validation Cost [1.0866009]
# Validation Accuracy [0.62539989]
# Epoch 85, CIFAR-10 Batch 3:  Validation Cost [1.1239988]
# Validation Accuracy [0.61519992]
# Epoch 85, CIFAR-10 Batch 4:  Validation Cost [1.0683457]
# Validation Accuracy [0.63259989]
# Epoch 85, CIFAR-10 Batch 5:  Validation Cost [1.0661962]
# Validation Accuracy [0.63359988]
# Epoch 86, CIFAR-10 Batch 1:  Validation Cost [1.0520478]
# Validation Accuracy [0.64539993]
# Epoch 86, CIFAR-10 Batch 2:  Validation Cost [1.0621675]
# Validation Accuracy [0.63699991]
# Epoch 86, CIFAR-10 Batch 3:  Validation Cost [1.075138]
# Validation Accuracy [0.62959987]
# Epoch 86, CIFAR-10 Batch 4:  Validation Cost [1.0844482]
# Validation Accuracy [0.6347999]
# Epoch 86, CIFAR-10 Batch 5:  Validation Cost [1.0862958]
# Validation Accuracy [0.6279999]
# Epoch 87, CIFAR-10 Batch 1:  Validation Cost [1.0655822]
# Validation Accuracy [0.63099992]
# Epoch 87, CIFAR-10 Batch 2:  Validation Cost [1.0580389]
# Validation Accuracy [0.63619989]
# Epoch 87, CIFAR-10 Batch 3:  Validation Cost [1.0679505]
# Validation Accuracy [0.63219988]
# Epoch 87, CIFAR-10 Batch 4:  Validation Cost [1.0596465]
# Validation Accuracy [0.64039993]
# Epoch 87, CIFAR-10 Batch 5:  Validation Cost [1.0602863]
# Validation Accuracy [0.63919991]
# Epoch 88, CIFAR-10 Batch 1:  Validation Cost [1.0439851]
# Validation Accuracy [0.64699996]
# Epoch 88, CIFAR-10 Batch 2:  Validation Cost [1.0945811]
# Validation Accuracy [0.62399989]
# Epoch 88, CIFAR-10 Batch 3:  Validation Cost [1.0600482]
# Validation Accuracy [0.63619995]
# Epoch 88, CIFAR-10 Batch 4:  Validation Cost [1.0713218]
# Validation Accuracy [0.64639986]
# Epoch 88, CIFAR-10 Batch 5:  Validation Cost [1.0941927]
# Validation Accuracy [0.6279999]
# Epoch 89, CIFAR-10 Batch 1:  Validation Cost [1.0483981]
# Validation Accuracy [0.64959985]
# Epoch 89, CIFAR-10 Batch 2:  Validation Cost [1.0674543]
# Validation Accuracy [0.63559985]
# Epoch 89, CIFAR-10 Batch 3:  Validation Cost [1.06458]
# Validation Accuracy [0.64059991]
# Epoch 89, CIFAR-10 Batch 4:  Validation Cost [1.0466552]
# Validation Accuracy [0.63879997]
# Epoch 89, CIFAR-10 Batch 5:  Validation Cost [1.0868777]
# Validation Accuracy [0.62899989]
# Epoch 90, CIFAR-10 Batch 1:  Validation Cost [1.0438308]
# Validation Accuracy [0.64579988]
# Epoch 90, CIFAR-10 Batch 2:  Validation Cost [1.0482397]
# Validation Accuracy [0.63939989]
# Epoch 90, CIFAR-10 Batch 3:  Validation Cost [1.0793459]
# Validation Accuracy [0.63039994]
# Epoch 90, CIFAR-10 Batch 4:  Validation Cost [1.0632656]
# Validation Accuracy [0.64039987]
# Epoch 90, CIFAR-10 Batch 5:  Validation Cost [1.069024]
# Validation Accuracy [0.63719988]
# Epoch 91, CIFAR-10 Batch 1:  Validation Cost [1.0516996]
# Validation Accuracy [0.64139986]
# Epoch 91, CIFAR-10 Batch 2:  Validation Cost [1.0484354]
# Validation Accuracy [0.64239991]
# Epoch 91, CIFAR-10 Batch 3:  Validation Cost [1.0695921]
# Validation Accuracy [0.62679994]
# Epoch 91, CIFAR-10 Batch 4:  Validation Cost [1.0631926]
# Validation Accuracy [0.63939989]
# Epoch 91, CIFAR-10 Batch 5:  Validation Cost [1.0751998]
# Validation Accuracy [0.63039988]
# Epoch 92, CIFAR-10 Batch 1:  Validation Cost [1.0382634]
# Validation Accuracy [0.64839989]
# Epoch 92, CIFAR-10 Batch 2:  Validation Cost [1.0454848]
# Validation Accuracy [0.63919991]
# Epoch 92, CIFAR-10 Batch 3:  Validation Cost [1.0418123]
# Validation Accuracy [0.64799988]
# Epoch 92, CIFAR-10 Batch 4:  Validation Cost [1.0708989]
# Validation Accuracy [0.63539988]
# Epoch 92, CIFAR-10 Batch 5:  Validation Cost [1.0947486]
# Validation Accuracy [0.62419987]
# Epoch 93, CIFAR-10 Batch 1:  Validation Cost [1.0265733]
# Validation Accuracy [0.65139991]
# Epoch 93, CIFAR-10 Batch 2:  Validation Cost [1.0525908]
# Validation Accuracy [0.63719994]
# Epoch 93, CIFAR-10 Batch 3:  Validation Cost [1.0658789]
# Validation Accuracy [0.63379991]
# Epoch 93, CIFAR-10 Batch 4:  Validation Cost [1.0500252]
# Validation Accuracy [0.63999987]
# Epoch 93, CIFAR-10 Batch 5:  Validation Cost [1.0971349]
# Validation Accuracy [0.61879992]
# Epoch 94, CIFAR-10 Batch 1:  Validation Cost [1.0430572]
# Validation Accuracy [0.63819987]
# Epoch 94, CIFAR-10 Batch 2:  Validation Cost [1.0567342]
# Validation Accuracy [0.63859987]
# Epoch 94, CIFAR-10 Batch 3:  Validation Cost [1.0707345]
# Validation Accuracy [0.63959992]
# Epoch 94, CIFAR-10 Batch 4:  Validation Cost [1.0563514]
# Validation Accuracy [0.63559991]
# Epoch 94, CIFAR-10 Batch 5:  Validation Cost [1.0416495]
# Validation Accuracy [0.6487999]
# Epoch 95, CIFAR-10 Batch 1:  Validation Cost [1.0592909]
# Validation Accuracy [0.63979989]
# Epoch 95, CIFAR-10 Batch 2:  Validation Cost [1.0636338]
# Validation Accuracy [0.64059991]
# Epoch 95, CIFAR-10 Batch 3:  Validation Cost [1.0401719]
# Validation Accuracy [0.64539993]
# Epoch 95, CIFAR-10 Batch 4:  Validation Cost [1.0542773]
# Validation Accuracy [0.6419999]
# Epoch 95, CIFAR-10 Batch 5:  Validation Cost [1.1025188]
# Validation Accuracy [0.62719989]
# Epoch 96, CIFAR-10 Batch 1:  Validation Cost [1.0406865]
# Validation Accuracy [0.64719987]
# Epoch 96, CIFAR-10 Batch 2:  Validation Cost [1.0724313]
# Validation Accuracy [0.62919992]
# Epoch 96, CIFAR-10 Batch 3:  Validation Cost [1.0510337]
# Validation Accuracy [0.64159989]
# Epoch 96, CIFAR-10 Batch 4:  Validation Cost [1.0525341]
# Validation Accuracy [0.64199984]
# Epoch 96, CIFAR-10 Batch 5:  Validation Cost [1.0605614]
# Validation Accuracy [0.63579988]
# Epoch 97, CIFAR-10 Batch 1:  Validation Cost [1.0544441]
# Validation Accuracy [0.63679993]
# Epoch 97, CIFAR-10 Batch 2:  Validation Cost [1.0583131]
# Validation Accuracy [0.64099985]
# Epoch 97, CIFAR-10 Batch 3:  Validation Cost [1.0919631]
# Validation Accuracy [0.61979985]
# Epoch 97, CIFAR-10 Batch 4:  Validation Cost [1.0459077]
# Validation Accuracy [0.63619989]
# Epoch 97, CIFAR-10 Batch 5:  Validation Cost [1.0476308]
# Validation Accuracy [0.64619988]
# Epoch 98, CIFAR-10 Batch 1:  Validation Cost [1.0428144]
# Validation Accuracy [0.6505999]
# Epoch 98, CIFAR-10 Batch 2:  Validation Cost [1.0413725]
# Validation Accuracy [0.64219993]
# Epoch 98, CIFAR-10 Batch 3:  Validation Cost [1.047577]
# Validation Accuracy [0.63899994]
# Epoch 98, CIFAR-10 Batch 4:  Validation Cost [1.0316302]
# Validation Accuracy [0.64539987]
# Epoch 98, CIFAR-10 Batch 5:  Validation Cost [1.0490863]
# Validation Accuracy [0.6365999]
# Epoch 99, CIFAR-10 Batch 1:  Validation Cost [1.0504602]
# Validation Accuracy [0.64059991]
# Epoch 99, CIFAR-10 Batch 2:  Validation Cost [1.0615054]
# Validation Accuracy [0.6383999]
# Epoch 99, CIFAR-10 Batch 3:  Validation Cost [1.0353277]
# Validation Accuracy [0.64519995]
# Epoch 99, CIFAR-10 Batch 4:  Validation Cost [1.0630459]
# Validation Accuracy [0.64279985]
# Epoch 99, CIFAR-10 Batch 5:  Validation Cost [1.0562582]
# Validation Accuracy [0.63899988]
# Epoch 100, CIFAR-10 Batch 1:  Validation Cost [1.0180285]
# Validation Accuracy [0.6509999]
# Epoch 100, CIFAR-10 Batch 2:  Validation Cost [1.0335606]
# Validation Accuracy [0.64079994]
# Epoch 100, CIFAR-10 Batch 3:  Validation Cost [1.0346177]
# Validation Accuracy [0.6437999]
# Epoch 100, CIFAR-10 Batch 4:  Validation Cost [1.0343027]
# Validation Accuracy [0.64359987]
# Epoch 100, CIFAR-10 Batch 5:  Validation Cost [1.035167]
# Validation Accuracy [0.64539993]
# Epoch 101, CIFAR-10 Batch 1:  Validation Cost [1.0984462]
# Validation Accuracy [0.62279987]
# Epoch 101, CIFAR-10 Batch 2:  Validation Cost [1.0401531]
# Validation Accuracy [0.6473999]
# Epoch 101, CIFAR-10 Batch 3:  Validation Cost [1.0510232]
# Validation Accuracy [0.64099991]
# Epoch 101, CIFAR-10 Batch 4:  Validation Cost [1.0432681]
# Validation Accuracy [0.64619988]
# Epoch 101, CIFAR-10 Batch 5:  Validation Cost [1.0192006]
# Validation Accuracy [0.64839995]
# Epoch 102, CIFAR-10 Batch 1:  Validation Cost [1.0472776]
# Validation Accuracy [0.64279991]
# Epoch 102, CIFAR-10 Batch 2:  Validation Cost [1.0468807]
# Validation Accuracy [0.64359993]
# Epoch 102, CIFAR-10 Batch 3:  Validation Cost [1.0363615]
# Validation Accuracy [0.64039987]
# Epoch 102, CIFAR-10 Batch 4:  Validation Cost [1.0467043]
# Validation Accuracy [0.64639986]
# Epoch 102, CIFAR-10 Batch 5:  Validation Cost [1.0422928]
# Validation Accuracy [0.64779991]
# Epoch 103, CIFAR-10 Batch 1:  Validation Cost [1.0200994]
# Validation Accuracy [0.64939988]
# Epoch 103, CIFAR-10 Batch 2:  Validation Cost [1.047202]
# Validation Accuracy [0.64479989]
# Epoch 103, CIFAR-10 Batch 3:  Validation Cost [1.0241919]
# Validation Accuracy [0.64559984]
# Epoch 103, CIFAR-10 Batch 4:  Validation Cost [1.0362918]
# Validation Accuracy [0.65099984]
# Epoch 103, CIFAR-10 Batch 5:  Validation Cost [1.0531271]
# Validation Accuracy [0.63919985]
# Epoch 104, CIFAR-10 Batch 1:  Validation Cost [1.0544455]
# Validation Accuracy [0.63999993]
# Epoch 104, CIFAR-10 Batch 2:  Validation Cost [1.0393131]
# Validation Accuracy [0.63899982]
# Epoch 104, CIFAR-10 Batch 3:  Validation Cost [1.0319419]
# Validation Accuracy [0.64079988]
# Epoch 104, CIFAR-10 Batch 4:  Validation Cost [1.0130465]
# Validation Accuracy [0.6505999]
# Epoch 104, CIFAR-10 Batch 5:  Validation Cost [1.0495454]
# Validation Accuracy [0.65079993]
# Epoch 105, CIFAR-10 Batch 1:  Validation Cost [1.0318583]
# Validation Accuracy [0.64779991]
# Epoch 105, CIFAR-10 Batch 2:  Validation Cost [1.0234601]
# Validation Accuracy [0.65259981]
# Epoch 105, CIFAR-10 Batch 3:  Validation Cost [1.0361878]
# Validation Accuracy [0.64139986]
# Epoch 105, CIFAR-10 Batch 4:  Validation Cost [1.0250831]
# Validation Accuracy [0.64999986]
# Epoch 105, CIFAR-10 Batch 5:  Validation Cost [1.068733]
# Validation Accuracy [0.63899988]
# Epoch 106, CIFAR-10 Batch 1:  Validation Cost [1.0370042]
# Validation Accuracy [0.65179992]
# Epoch 106, CIFAR-10 Batch 2:  Validation Cost [1.0306915]
# Validation Accuracy [0.64639992]
# Epoch 106, CIFAR-10 Batch 3:  Validation Cost [1.0507915]
# Validation Accuracy [0.63719994]
# Epoch 106, CIFAR-10 Batch 4:  Validation Cost [1.0529872]
# Validation Accuracy [0.63979983]
# Epoch 106, CIFAR-10 Batch 5:  Validation Cost [1.0255952]
# Validation Accuracy [0.64599985]
# Epoch 107, CIFAR-10 Batch 1:  Validation Cost [1.0423086]
# Validation Accuracy [0.63919991]
# Epoch 107, CIFAR-10 Batch 2:  Validation Cost [1.0405872]
# Validation Accuracy [0.64279991]
# Epoch 107, CIFAR-10 Batch 3:  Validation Cost [1.0329651]
# Validation Accuracy [0.64839989]
# Epoch 107, CIFAR-10 Batch 4:  Validation Cost [1.0306646]
# Validation Accuracy [0.64859986]
# ...
# Epoch 166, CIFAR-10 Batch 1:  Validation Cost [0.99167609]
# Validation Accuracy [0.66239989]
# Epoch 166, CIFAR-10 Batch 2:  Validation Cost [0.97363168]
# Validation Accuracy [0.66759986]
# Epoch 166, CIFAR-10 Batch 3:  Validation Cost [1.0224684]
# Validation Accuracy [0.6473999]
# Epoch 166, CIFAR-10 Batch 4:  Validation Cost [1.0194712]
# Validation Accuracy [0.65739983]
# Epoch 166, CIFAR-10 Batch 5:  Validation Cost [0.97975093]
# Validation Accuracy [0.6717999]
# Epoch 167, CIFAR-10 Batch 1:  Validation Cost [0.97800565]
# Validation Accuracy [0.6667999]
# Epoch 167, CIFAR-10 Batch 2:  Validation Cost [0.98389393]
# Validation Accuracy [0.65979993]
# Epoch 167, CIFAR-10 Batch 3:  Validation Cost [0.99556726]
# Validation Accuracy [0.66079986]
# Epoch 167, CIFAR-10 Batch 4:  Validation Cost [1.0067177]
# Validation Accuracy [0.65899986]
# Epoch 167, CIFAR-10 Batch 5:  Validation Cost [1.0068164]
# Validation Accuracy [0.65999991]
# Epoch 168, CIFAR-10 Batch 1:  Validation Cost [1.0048656]
# Validation Accuracy [0.65739989]
# Epoch 168, CIFAR-10 Batch 2:  Validation Cost [0.98729324]
# Validation Accuracy [0.66059995]
# Epoch 168, CIFAR-10 Batch 3:  Validation Cost [0.99463487]
# Validation Accuracy [0.6541999]
# Epoch 168, CIFAR-10 Batch 4:  Validation Cost [0.99635983]
# Validation Accuracy [0.66199994]
# Epoch 168, CIFAR-10 Batch 5:  Validation Cost [0.99361205]
# Validation Accuracy [0.65819991]
# Epoch 169, CIFAR-10 Batch 1:  Validation Cost [0.98541933]
# Validation Accuracy [0.66379988]
# Epoch 169, CIFAR-10 Batch 2:  Validation Cost [0.9929564]
# Validation Accuracy [0.65739989]
# Epoch 169, CIFAR-10 Batch 3:  Validation Cost [0.99099684]
# Validation Accuracy [0.6663999]
# Epoch 169, CIFAR-10 Batch 4:  Validation Cost [0.99272352]
# Validation Accuracy [0.66259992]
# Epoch 169, CIFAR-10 Batch 5:  Validation Cost [0.98892891]
# Validation Accuracy [0.66739982]
# Epoch 170, CIFAR-10 Batch 1:  Validation Cost [0.98950452]
# Validation Accuracy [0.66459984]
# Epoch 170, CIFAR-10 Batch 2:  Validation Cost [1.0226357]
# Validation Accuracy [0.6509999]
# Epoch 170, CIFAR-10 Batch 3:  Validation Cost [1.0147198]
# Validation Accuracy [0.65759993]
# Epoch 170, CIFAR-10 Batch 4:  Validation Cost [1.0009153]
# Validation Accuracy [0.66299987]
# Epoch 170, CIFAR-10 Batch 5:  Validation Cost [0.99530637]
# Validation Accuracy [0.66079986]
# Epoch 171, CIFAR-10 Batch 1:  Validation Cost [1.0121992]
# Validation Accuracy [0.65399992]
# Epoch 171, CIFAR-10 Batch 2:  Validation Cost [1.0186213]
# Validation Accuracy [0.65319985]
# Epoch 171, CIFAR-10 Batch 3:  Validation Cost [1.0029199]
# Validation Accuracy [0.66479987]
# Epoch 171, CIFAR-10 Batch 4:  Validation Cost [1.0035456]
# Validation Accuracy [0.66659993]
# Epoch 171, CIFAR-10 Batch 5:  Validation Cost [1.034111]
# Validation Accuracy [0.65059996]
# Epoch 172, CIFAR-10 Batch 1:  Validation Cost [0.9909668]
# Validation Accuracy [0.66219991]
# Epoch 172, CIFAR-10 Batch 2:  Validation Cost [1.0079265]
# Validation Accuracy [0.65579993]
# Epoch 172, CIFAR-10 Batch 3:  Validation Cost [1.0009043]
# Validation Accuracy [0.65559989]
# Epoch 172, CIFAR-10 Batch 4:  Validation Cost [0.99359357]
# Validation Accuracy [0.66299987]
# Epoch 172, CIFAR-10 Batch 5:  Validation Cost [1.0370345]
# Validation Accuracy [0.64179987]
# Epoch 173, CIFAR-10 Batch 1:  Validation Cost [0.99177653]
# Validation Accuracy [0.66839993]
# Epoch 173, CIFAR-10 Batch 2:  Validation Cost [0.99353015]
# Validation Accuracy [0.65759987]
# Epoch 173, CIFAR-10 Batch 3:  Validation Cost [0.99021858]
# Validation Accuracy [0.66059995]
# Epoch 173, CIFAR-10 Batch 4:  Validation Cost [1.0153806]
# Validation Accuracy [0.6631999]
# Epoch 173, CIFAR-10 Batch 5:  Validation Cost [0.97843575]
# Validation Accuracy [0.66979992]
# Epoch 174, CIFAR-10 Batch 1:  Validation Cost [0.98675585]
# Validation Accuracy [0.66199988]
# Epoch 174, CIFAR-10 Batch 2:  Validation Cost [0.99321032]
# Validation Accuracy [0.66339993]
# Epoch 174, CIFAR-10 Batch 3:  Validation Cost [0.99432826]
# Validation Accuracy [0.66659987]
# Epoch 174, CIFAR-10 Batch 4:  Validation Cost [1.0004051]
# Validation Accuracy [0.6577999]
# Epoch 174, CIFAR-10 Batch 5:  Validation Cost [0.99591047]
# Validation Accuracy [0.66139984]
# Epoch 175, CIFAR-10 Batch 1:  Validation Cost [1.0292449]
# Validation Accuracy [0.66659999]
# Epoch 175, CIFAR-10 Batch 2:  Validation Cost [0.99384046]
# Validation Accuracy [0.66519988]
# Epoch 175, CIFAR-10 Batch 3:  Validation Cost [1.0023953]
# Validation Accuracy [0.66239989]
# Epoch 175, CIFAR-10 Batch 4:  Validation Cost [1.0302219]
# Validation Accuracy [0.65079987]
# Epoch 175, CIFAR-10 Batch 5:  Validation Cost [0.98774123]
# Validation Accuracy [0.66039985]
# Epoch 176, CIFAR-10 Batch 1:  Validation Cost [1.0204172]
# Validation Accuracy [0.65499985]
# Epoch 176, CIFAR-10 Batch 2:  Validation Cost [0.98851258]
# Validation Accuracy [0.66339988]
# Epoch 176, CIFAR-10 Batch 3:  Validation Cost [1.0011851]
# Validation Accuracy [0.65179992]
# Epoch 176, CIFAR-10 Batch 4:  Validation Cost [1.0332415]
# Validation Accuracy [0.6595999]
# Epoch 176, CIFAR-10 Batch 5:  Validation Cost [0.98344779]
# Validation Accuracy [0.66839993]
# Epoch 177, CIFAR-10 Batch 1:  Validation Cost [1.0102803]
# Validation Accuracy [0.66139996]
# Epoch 177, CIFAR-10 Batch 2:  Validation Cost [0.9789573]
# Validation Accuracy [0.67339993]
# Epoch 177, CIFAR-10 Batch 3:  Validation Cost [0.98139644]
# Validation Accuracy [0.66519982]
# Epoch 177, CIFAR-10 Batch 4:  Validation Cost [1.0082605]
# Validation Accuracy [0.65939987]
# Epoch 177, CIFAR-10 Batch 5:  Validation Cost [0.9984073]
# Validation Accuracy [0.66959989]
# Epoch 178, CIFAR-10 Batch 1:  Validation Cost [0.99452192]
# Validation Accuracy [0.66339988]
# Epoch 178, CIFAR-10 Batch 2:  Validation Cost [1.0046682]
# Validation Accuracy [0.65359986]
# Epoch 178, CIFAR-10 Batch 3:  Validation Cost [0.97753108]
# Validation Accuracy [0.67319989]
# Epoch 178, CIFAR-10 Batch 4:  Validation Cost [1.001555]
# Validation Accuracy [0.66199988]
# Epoch 178, CIFAR-10 Batch 5:  Validation Cost [0.97869974]
# Validation Accuracy [0.66739988]
# Epoch 179, CIFAR-10 Batch 1:  Validation Cost [0.99326605]
# Validation Accuracy [0.66499984]
# Epoch 179, CIFAR-10 Batch 2:  Validation Cost [1.0050516]
# Validation Accuracy [0.6595999]
# Epoch 179, CIFAR-10 Batch 3:  Validation Cost [1.009554]
# Validation Accuracy [0.65359986]
# Epoch 179, CIFAR-10 Batch 4:  Validation Cost [1.0220108]
# Validation Accuracy [0.65199983]
# Epoch 179, CIFAR-10 Batch 5:  Validation Cost [0.99876863]
# Validation Accuracy [0.6645999]
# Epoch 180, CIFAR-10 Batch 1:  Validation Cost [0.98319197]
# Validation Accuracy [0.66939992]
# Epoch 180, CIFAR-10 Batch 2:  Validation Cost [1.0004065]
# Validation Accuracy [0.66279989]
# Epoch 180, CIFAR-10 Batch 3:  Validation Cost [0.98487359]
# Validation Accuracy [0.66899991]
# Epoch 180, CIFAR-10 Batch 4:  Validation Cost [1.0181259]
# Validation Accuracy [0.65439993]
# Epoch 180, CIFAR-10 Batch 5:  Validation Cost [1.0013595]
# Validation Accuracy [0.66059983]
# Epoch 181, CIFAR-10 Batch 1:  Validation Cost [0.98221844]
# Validation Accuracy [0.66799986]
# Epoch 181, CIFAR-10 Batch 2:  Validation Cost [0.99717283]
# Validation Accuracy [0.66599989]
# Epoch 181, CIFAR-10 Batch 3:  Validation Cost [0.99575597]
# Validation Accuracy [0.6649999]
# Epoch 181, CIFAR-10 Batch 4:  Validation Cost [0.98903549]
# Validation Accuracy [0.66879988]
# Epoch 181, CIFAR-10 Batch 5:  Validation Cost [1.0348871]
# Validation Accuracy [0.65299994]
# Epoch 182, CIFAR-10 Batch 1:  Validation Cost [1.0024821]
# Validation Accuracy [0.65899992]
# Epoch 182, CIFAR-10 Batch 2:  Validation Cost [1.05371]
# Validation Accuracy [0.63279986]
# Epoch 182, CIFAR-10 Batch 3:  Validation Cost [0.99685544]
# Validation Accuracy [0.66279989]
# Epoch 182, CIFAR-10 Batch 4:  Validation Cost [0.97506332]
# Validation Accuracy [0.66879988]
# Epoch 182, CIFAR-10 Batch 5:  Validation Cost [0.99516362]
# Validation Accuracy [0.66159987]
# Epoch 183, CIFAR-10 Batch 1:  Validation Cost [1.0213258]
# Validation Accuracy [0.65919989]
# Epoch 183, CIFAR-10 Batch 2:  Validation Cost [0.9997794]
# Validation Accuracy [0.65659988]
# Epoch 183, CIFAR-10 Batch 3:  Validation Cost [0.99242854]
# Validation Accuracy [0.66059989]
# Epoch 183, CIFAR-10 Batch 4:  Validation Cost [0.97536081]
# Validation Accuracy [0.66979986]
# Epoch 183, CIFAR-10 Batch 5:  Validation Cost [0.98831874]
# Validation Accuracy [0.66219985]
# Epoch 184, CIFAR-10 Batch 1:  Validation Cost [0.98971272]
# Validation Accuracy [0.66259986]
# Epoch 184, CIFAR-10 Batch 2:  Validation Cost [0.98247713]
# Validation Accuracy [0.66859984]
# Epoch 184, CIFAR-10 Batch 3:  Validation Cost [1.0144933]
# Validation Accuracy [0.6559999]
# Epoch 184, CIFAR-10 Batch 4:  Validation Cost [0.98698938]
# Validation Accuracy [0.6681999]
# Epoch 184, CIFAR-10 Batch 5:  Validation Cost [0.96463794]
# Validation Accuracy [0.67139989]
# Epoch 185, CIFAR-10 Batch 1:  Validation Cost [0.97881508]
# Validation Accuracy [0.66739982]
# Epoch 185, CIFAR-10 Batch 2:  Validation Cost [0.99276292]
# Validation Accuracy [0.66199988]
# Epoch 185, CIFAR-10 Batch 3:  Validation Cost [1.0086145]
# Validation Accuracy [0.66019988]
# Epoch 185, CIFAR-10 Batch 4:  Validation Cost [1.0083681]
# Validation Accuracy [0.65859985]
# Epoch 185, CIFAR-10 Batch 5:  Validation Cost [0.99403924]
# Validation Accuracy [0.66899991]
# Epoch 186, CIFAR-10 Batch 1:  Validation Cost [0.98581898]
# Validation Accuracy [0.66799986]
# Epoch 186, CIFAR-10 Batch 2:  Validation Cost [1.0215691]
# Validation Accuracy [0.6559999]
# Epoch 186, CIFAR-10 Batch 3:  Validation Cost [0.99342144]
# Validation Accuracy [0.66699988]
# Epoch 186, CIFAR-10 Batch 4:  Validation Cost [0.97647512]
# Validation Accuracy [0.67379987]
# Epoch 186, CIFAR-10 Batch 5:  Validation Cost [0.99292058]
# Validation Accuracy [0.67059982]
# Epoch 187, CIFAR-10 Batch 1:  Validation Cost [0.97786516]
# Validation Accuracy [0.67019987]
# Epoch 187, CIFAR-10 Batch 2:  Validation Cost [0.98230577]
# Validation Accuracy [0.66859984]
# Epoch 187, CIFAR-10 Batch 3:  Validation Cost [1.0445364]
# Validation Accuracy [0.65019995]
# Epoch 187, CIFAR-10 Batch 4:  Validation Cost [0.99662042]
# Validation Accuracy [0.66659987]
# Epoch 187, CIFAR-10 Batch 5:  Validation Cost [1.0250342]
# Validation Accuracy [0.65459991]
# Epoch 188, CIFAR-10 Batch 1:  Validation Cost [0.99244183]
# Validation Accuracy [0.66899985]
# Epoch 188, CIFAR-10 Batch 2:  Validation Cost [0.97964662]
# Validation Accuracy [0.67059988]
# Epoch 188, CIFAR-10 Batch 3:  Validation Cost [0.99331856]
# Validation Accuracy [0.66559988]
# Epoch 188, CIFAR-10 Batch 4:  Validation Cost [0.98870504]
# Validation Accuracy [0.66699988]
# Epoch 188, CIFAR-10 Batch 5:  Validation Cost [0.9758718]
# Validation Accuracy [0.66979992]
# Epoch 189, CIFAR-10 Batch 1:  Validation Cost [0.99663198]
# Validation Accuracy [0.67139995]
# Epoch 189, CIFAR-10 Batch 2:  Validation Cost [0.98023289]
# Validation Accuracy [0.6717999]
# Epoch 189, CIFAR-10 Batch 3:  Validation Cost [1.0030441]
# Validation Accuracy [0.66199988]
# Epoch 189, CIFAR-10 Batch 4:  Validation Cost [0.9932822]
# Validation Accuracy [0.66559988]
# Epoch 189, CIFAR-10 Batch 5:  Validation Cost [0.99212903]
# Validation Accuracy [0.66299987]
# Epoch 190, CIFAR-10 Batch 1:  Validation Cost [0.98028833]
# Validation Accuracy [0.66339988]
# Epoch 190, CIFAR-10 Batch 2:  Validation Cost [0.98650134]
# Validation Accuracy [0.66519988]
# Epoch 190, CIFAR-10 Batch 3:  Validation Cost [1.0064315]
# Validation Accuracy [0.65799987]
# Epoch 190, CIFAR-10 Batch 4:  Validation Cost [0.99390095]
# Validation Accuracy [0.66979986]
# Epoch 190, CIFAR-10 Batch 5:  Validation Cost [0.99985182]
# Validation Accuracy [0.65799993]
# Epoch 191, CIFAR-10 Batch 1:  Validation Cost [0.98827767]
# Validation Accuracy [0.66419989]
# Epoch 191, CIFAR-10 Batch 2:  Validation Cost [1.012381]
# Validation Accuracy [0.65679991]
# Epoch 191, CIFAR-10 Batch 3:  Validation Cost [0.98251075]
# Validation Accuracy [0.67079985]
# Epoch 191, CIFAR-10 Batch 4:  Validation Cost [1.0026369]
# Validation Accuracy [0.66839987]
# Epoch 191, CIFAR-10 Batch 5:  Validation Cost [0.98483413]
# Validation Accuracy [0.66599989]
# Epoch 192, CIFAR-10 Batch 1:  Validation Cost [0.97808176]
# Validation Accuracy [0.6721999]
# Epoch 192, CIFAR-10 Batch 2:  Validation Cost [0.97768945]
# Validation Accuracy [0.67059988]
# Epoch 192, CIFAR-10 Batch 3:  Validation Cost [0.99454498]
# Validation Accuracy [0.66159987]
# Epoch 192, CIFAR-10 Batch 4:  Validation Cost [0.99886787]
# Validation Accuracy [0.66159993]
# Epoch 192, CIFAR-10 Batch 5:  Validation Cost [0.98437393]
# Validation Accuracy [0.67139989]
# Epoch 193, CIFAR-10 Batch 1:  Validation Cost [0.99194026]
# Validation Accuracy [0.67139983]
# Epoch 193, CIFAR-10 Batch 2:  Validation Cost [0.99186462]
# Validation Accuracy [0.66779989]
# Epoch 193, CIFAR-10 Batch 3:  Validation Cost [1.0275363]
# Validation Accuracy [0.6523999]
# Epoch 193, CIFAR-10 Batch 4:  Validation Cost [1.0672671]
# Validation Accuracy [0.63859987]
# Epoch 193, CIFAR-10 Batch 5:  Validation Cost [1.0054671]
# Validation Accuracy [0.66179991]
# Epoch 194, CIFAR-10 Batch 1:  Validation Cost [0.97894794]
# Validation Accuracy [0.6703999]
# Epoch 194, CIFAR-10 Batch 2:  Validation Cost [0.99395323]
# Validation Accuracy [0.65979987]
# Epoch 194, CIFAR-10 Batch 3:  Validation Cost [0.99192208]
# Validation Accuracy [0.66739988]
# Epoch 194, CIFAR-10 Batch 4:  Validation Cost [0.97873783]
# Validation Accuracy [0.67739987]
# Epoch 194, CIFAR-10 Batch 5:  Validation Cost [0.97726011]
# Validation Accuracy [0.67199981]
# Epoch 195, CIFAR-10 Batch 1:  Validation Cost [0.97104907]
# Validation Accuracy [0.67479986]
# Epoch 195, CIFAR-10 Batch 2:  Validation Cost [0.98100889]
# Validation Accuracy [0.66939986]
# Epoch 195, CIFAR-10 Batch 3:  Validation Cost [0.99445719]
# Validation Accuracy [0.66159993]
# Epoch 195, CIFAR-10 Batch 4:  Validation Cost [1.0019276]
# Validation Accuracy [0.66099989]
# Epoch 195, CIFAR-10 Batch 5:  Validation Cost [0.99702531]
# Validation Accuracy [0.66239989]
# Epoch 196, CIFAR-10 Batch 1:  Validation Cost [0.98058218]
# Validation Accuracy [0.66779983]
# Epoch 196, CIFAR-10 Batch 2:  Validation Cost [1.0016253]
# Validation Accuracy [0.66019988]
# Epoch 196, CIFAR-10 Batch 3:  Validation Cost [0.9990108]
# Validation Accuracy [0.67019993]
# Epoch 196, CIFAR-10 Batch 4:  Validation Cost [0.98676574]
# Validation Accuracy [0.67699993]
# Epoch 196, CIFAR-10 Batch 5:  Validation Cost [0.99315339]
# Validation Accuracy [0.65819985]
# Epoch 197, CIFAR-10 Batch 1:  Validation Cost [0.98256743]
# Validation Accuracy [0.66579992]
# Epoch 197, CIFAR-10 Batch 2:  Validation Cost [0.9797892]
# Validation Accuracy [0.66719985]
# Epoch 197, CIFAR-10 Batch 3:  Validation Cost [1.0055413]
# Validation Accuracy [0.65699983]
# Epoch 197, CIFAR-10 Batch 4:  Validation Cost [1.0179749]
# Validation Accuracy [0.65439987]
# Epoch 197, CIFAR-10 Batch 5:  Validation Cost [0.98016477]
# Validation Accuracy [0.66979992]
# Epoch 198, CIFAR-10 Batch 1:  Validation Cost [1.0604252]
# Validation Accuracy [0.64319992]
# Epoch 198, CIFAR-10 Batch 2:  Validation Cost [0.9712522]
# Validation Accuracy [0.67399991]
# Epoch 198, CIFAR-10 Batch 3:  Validation Cost [0.99377429]
# Validation Accuracy [0.66259986]
# Epoch 198, CIFAR-10 Batch 4:  Validation Cost [1.060611]
# Validation Accuracy [0.64399993]
# Epoch 198, CIFAR-10 Batch 5:  Validation Cost [0.99711585]
# Validation Accuracy [0.66359985]
# Epoch 199, CIFAR-10 Batch 1:  Validation Cost [0.98478544]
# Validation Accuracy [0.66619992]
# Epoch 199, CIFAR-10 Batch 2:  Validation Cost [1.0107995]
# Validation Accuracy [0.65879989]
# Epoch 199, CIFAR-10 Batch 3:  Validation Cost [0.98925024]
# Validation Accuracy [0.6645999]
# Epoch 199, CIFAR-10 Batch 4:  Validation Cost [0.97854263]
# Validation Accuracy [0.67699993]
# Epoch 199, CIFAR-10 Batch 5:  Validation Cost [1.0230681]
# Validation Accuracy [0.6523999]
# Epoch 200, CIFAR-10 Batch 1:  Validation Cost [0.97896087]
# Validation Accuracy [0.66279984]
# Epoch 200, CIFAR-10 Batch 2:  Validation Cost [1.0218697]
# Validation Accuracy [0.65039986]
# Epoch 200, CIFAR-10 Batch 3:  Validation Cost [1.0163188]
# Validation Accuracy [0.65459985]
# Epoch 200, CIFAR-10 Batch 4:  Validation Cost [0.97843909]
# Validation Accuracy [0.67139989]
# Epoch 200, CIFAR-10 Batch 5:  Validation Cost [1.0501649]
# Validation Accuracy [0.64799988]

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6370421974522293

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
